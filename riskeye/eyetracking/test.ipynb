# %%
import pandas as pd

from riskeye.utils.data import Subject, get_all_subjects, get_all_behavior, get_all_subject_ids, get_all_eyepos_info
import seaborn as sns
import numpy as np
from tqdm.notebook import tqdm

# %%
saccades = get_all_eyepos_info(source='saccades')

# %%
beh = get_all_behavior()

# %%
df = beh.join(saccades)
df['risky_duration'] = df['left_duration'].where(df['p_left'] == 0.55, df['right_duration'])
df['safe_duration'] = df['left_duration'].where(df['p_left'] == 1.0, df['right_duration'])
df['fixation_duration'] = df['risky_duration'] + df['safe_duration']
df['risky_duration_prop'] = df['risky_duration'] / df['fixation_duration']
df['safe_duration_prop'] = df['safe_duration'] / df['fixation_duration']
df['risky_seen_first'] = ((df['first_saccade'] == 'left_option') & (df['p_left'] == 0.55)) | ((df['first_saccade'] == 'right_option') & (df['p_right'] == 0.55))
df['risky_seen_last'] = ((df['last_saccade'] == 'left_option') & (df['p_left'] == 0.55)) | ((df['last_saccade'] == 'right_option') & (df['p_right'] == 0.55))
df['first_last_different'] = df['risky_seen_first'] != df['risky_seen_last']

# %%
# df['risky_duration_prop_split'] = df.groupby(['subject', 'exptype', 'n_safe', 'n_risky', 'p_left'], group_keys=False)['risky_duration_prop'].apply(lambda x: x > x.quantile() if len(x) > 1 else np.nan).map({True:'long', False:'short'})

# %%
sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', col='exptype', logistic=True, scatter=False)
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/2234460896.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', col='exptype', logistic=True, scatter=False)

# %%
sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', row='first_' col='exptype', logistic=True, scatter=False)

# %%
sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', col='exptype', logistic=True, scatter=False)

# %%
sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first', 'n_safe']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', row='exptype', col='n_safe', logistic=True, scatter=False)
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/2460470283.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first', 'n_safe']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', row='exptype', col='n_safe', logistic=True, scatter=False)

# %%
sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first', 'n_safe']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='n_safe', row='exptype', col='risky_seen_first', logistic=True, scatter=False)
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/3560568293.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first', 'n_safe']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='n_safe', row='exptype', col='risky_seen_first', logistic=True, scatter=False)

# %%
sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first', 'n_safe']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', row='exptype', col='n_safe', logistic=True, scatter=False)
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/2460470283.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first', 'n_safe']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', row='exptype', col='n_safe', logistic=True, scatter=False)

# %%
sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_last', 'n_safe']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_last', row='exptype', col='n_safe', logistic=True, scatter=False)
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/3666860031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_last', 'n_safe']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_last', row='exptype', col='n_safe', logistic=True, scatter=False)

# %%
sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', col='exptype', logistic=True, scatter=False)
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/2234460896.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lmplot(data=df.groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', col='exptype', logistic=True, scatter=False)

# %%
sns.lmplot(data=df[df['n_saccades'] == 2].groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_last']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_last', col='exptype', logistic=True, scatter=False)
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/2157326819.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lmplot(data=df[df['n_saccades'] == 2].groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_last']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_last', col='exptype', logistic=True, scatter=False)

# %%
sns.lmplot(data=df[df['n_saccades'] == 2].groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', col='exptype', logistic=True, scatter=False)
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/3451275594.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lmplot(data=df[df['n_saccades'] == 2].groupby(['subject', 'exptype', 'log(risky/safe)', 'risky_seen_first']).mean().reset_index(), x='log(risky/safe)', y='chose_risky', hue='risky_seen_first', col='exptype', logistic=True, scatter=False)

# %%
tmp = df.groupby(['subject', 'exptype', 'risky_seen_first', 'risky_seen_last', 'n_safe']).mean()

sns.catplot(x='n_safe', y='chose_risky', hue='risky_seen_first', col='risky_seen_last', row='exptype', data=tmp.reset_index(), kind='point', errorbar='se')
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/1246501723.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tmp = df.groupby(['subject', 'exptype', 'risky_seen_first', 'risky_seen_last', 'n_safe']).mean()

# %%
tmp = df.groupby(['subject', 'exptype', 'risky_duration_prop_split', 'n_safe']).mean()

sns.catplot(x='n_safe', y='chose_risky', hue='risky_duration_prop_split', col='exptype', data=tmp.reset_index(), kind='point', errorbar='se')
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/2935439589.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tmp = df.groupby(['subject', 'exptype', 'risky_duration_prop_split', 'n_safe']).mean()

# %%
df['risky_seen_less'] = df['risky_duration'] < df['safe_duration']

# %%
df['risky_duration'] = np.clip(df['risky_duration'], 0, 1000)

# %%
sns.lmplot(x='log(risky/safe)', y='risky_duration', data=df.reset_index(), hue='exptype', scatter=False)
sns.lmplot(x='log(risky/safe)', y='safe_duration', data=df.reset_index(), hue='exptype', scatter=False)

# %%
sns.catplot(x='n_safe', hue='risky_seen_less', y='log(risky/safe)', data=df.groupby(['subject', 'n_safe', 'risky_seen_less']).mean().reset_index(), kind='point')
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_12645/2900249529.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.catplot(x='n_safe', hue='risky_seen_less', y='log(risky/safe)', data=df.groupby(['subject', 'n_safe', 'risky_seen_less']).mean().reset_index(), kind='point')

# %%
saccades = []
for subject in tqdm(get_all_subjects()):
    try:
        saccades.append(subject.get_trialwise_saccade_info())
    except Exception as e:
        print(subject.subject_id, e)


saccades = pd.concat(saccades)
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
# 41 [Errno 2] No such file or directory: '/data/ds-riskeye/derivatives/pupil/sub-41/func/sub-41_saccades.tsv'

# %%
beh = get_all_behavior()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 beh = get_all_behavior()
#
# File ~/git/riskeye/riskeye/utils/data.py:12, in get_all_behavior(include_no_responses, bids_folder)
#      11 def get_all_behavior(include_no_responses=False, bids_folder='/data/ds-riskeye'):
# ---> 12     return pd.concat([e.get_behavior(include_no_responses=include_no_responses) for e in get_all_subject(bids_folder=bids_folder)])
#
# NameError: name 'get_all_subject' is not defined

# %%
Subject('52').get_eyetracker_timings()
# Out:
# subject  run  block  trial  type
# 52       1    1      1      rfx         13260186
#                             gfx         13261016
#                             response    13264017
#                      2      rfx         13265767
#                             gfx         13266577
#                                           ...
#          5    4      23     gfx         16304852
#                             response    16306986
#                      24     rfx         16309576
#                             gfx         16310388
#                             response    16312561
# Name: timestamp, Length: 1438, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Subject('52').get_saccades(merge_saccades=False)
#
# File ~/git/riskeye/riskeye/utils/data.py:50, in Subject.get_saccades(self, merge_saccades)
#      48 saccades_per_block = []
#      49 for ix, row in messages.iterrows():
# ---> 50     s = saccades.loc[(ix[0], ix[1], slice(row.gfx, row.response)), :]
#      51     saccades_per_block.append(s.droplevel([0, 1]))
#      53 saccades_per_block = pd.concat(saccades_per_block, keys=messages.index)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexing.py:1248, in _LocIndexer._getitem_tuple(self, tup)
#    1246 with suppress(IndexingError):
#    1247     tup = self._expand_ellipsis(tup)
# -> 1248     return self._getitem_lowerdim(tup)
#    1250 # no multi-index, so validate all of the indexers
#    1251 tup = self._validate_tuple_indexer(tup)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexing.py:942, in _LocationIndexer._getitem_lowerdim(self, tup)
#     940 # we may have a nested tuples indexer here
#     941 if self._is_nested_tuple_indexer(tup):
# --> 942     return self._getitem_nested_tuple(tup)
#     944 # we maybe be using a tuple to represent multiple dimensions here
#     945 ax0 = self.obj._get_axis(0)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexing.py:1048, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1045     axis -= 1
#    1046     continue
# -> 1048 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1049 axis -= 1
#    1051 # if we have a scalar, we are done
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexing.py:1306, in _LocIndexer._getitem_axis(self, key, axis)
#    1304 # nested tuple slicing
#    1305 if is_nested_tuple(key, labels):
# -> 1306     locs = labels.get_locs(key)
#    1307     indexer = [slice(None)] * self.ndim
#    1308     indexer[axis] = locs
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3330, in MultiIndex.get_locs(self, seq)
#    3328 true_slices = [i for (i, s) in enumerate(com.is_true_slices(seq)) if s]
#    3329 if true_slices and true_slices[-1] >= self._lexsort_depth:
# -> 3330     raise UnsortedIndexError(
#    3331         "MultiIndex slicing requires the index to be lexsorted: slicing "
#    3332         f"on levels {true_slices}, lexsort depth {self._lexsort_depth}"
#    3333     )
#    3335 if any(x is Ellipsis for x in seq):
#    3336     raise NotImplementedError(
#    3337         "MultiIndex does not support indexing with Ellipsis"
#    3338     )
#
# UnsortedIndexError: 'MultiIndex slicing requires the index to be lexsorted: slicing on levels [2], lexsort depth 2'

# %%
saccades.loc['52']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '52'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 saccades.loc['52']
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexing.py:1313, in _LocIndexer._getitem_axis(self, key, axis)
#    1311 # fall thru to straight lookup
#    1312 self._validate_key(key, axis)
# -> 1313 return self._get_label(key, axis=axis)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexing.py:1261, in _LocIndexer._get_label(self, label, axis)
#    1259 def _get_label(self, label, axis: int):
#    1260     # GH#5567 this will fail if the label is not present in the axis.
# -> 1261     return self.obj.xs(label, axis=axis)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/generic.py:4050, in NDFrame.xs(self, key, axis, level, drop_level)
#    4047 self._consolidate_inplace()
#    4049 if isinstance(index, MultiIndex):
# -> 4050     loc, new_index = index._get_loc_level(key, level=0)
#    4051     if not drop_level:
#    4052         if lib.is_integer(loc):
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3159, in MultiIndex._get_loc_level(self, key, level)
#    3157         return indexer, maybe_mi_droplevels(indexer, ilevels)
#    3158 else:
# -> 3159     indexer = self._get_level_indexer(key, level=level)
#    3160     if (
#    3161         isinstance(key, str)
#    3162         and self.levels[level]._supports_partial_string_indexing
#    3163     ):
#    3164         # check to see if we did an exact lookup vs sliced
#    3165         check = self.levels[level].get_loc(key)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3262, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3258         return slice(i, j, step)
#    3260 else:
# -> 3262     idx = self._get_loc_single_level_index(level_index, key)
#    3264     if level > 0 or self._lexsort_depth == 0:
#    3265         # Desired level is not sorted
#    3266         if isinstance(idx, slice):
#    3267             # test_get_loc_partial_timestamp_multiindex
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/multi.py:2848, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2846     return -1
#    2847 else:
# -> 2848     return level_index.get_loc(key)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: '52'

# %%
sub1 = Subject('01', '/data/ds-riskeye')
saccades = sub1.get_trialwise_saccade_info()

# %%
sub1 = Subject('01', '/data/ds-riskeye')
saccades1 = sub1.get_saccades()
messages = sub1.get_eyetracker_timings()
beh1 = sub1.get_behavior()

sub2 = Subject('02', '/data/ds-riskeye')
saccades2 = sub2.get_saccades()
beh2 = sub2.get_behavior()

sub3 = Subject('03', '/data/ds-riskeye')
saccades3 = sub3.get_saccades()

# sub4 = Subject('04', '/data/ds-riskeye')
# saccades4 = sub4.get_saccades()

# %%
def summarize_trial_saccades(d):
    d = d[np.in1d(d.fixation_target, ['left_option', 'right_option'])]

    durations = d.groupby('fixation_target')['duration'].sum() 
    # print(durations)

    if len(d) == 0:
        result = pd.DataFrame([{'n_saccades':0}])
    else:
        result = pd.DataFrame([{'n_saccades':len(d), 'first_saccade':d.iloc[0]['fixation_target'], 'last_saccade':d.iloc[-1]['fixation_target']}])
        result['left_duration'] = durations.loc['left_option'] if 'left_option' in durations.index else 0
        result['right_duration'] = durations.loc['right_option'] if 'right_option' in durations.index else 0

    return result

# %%
s_summary = saccades1.groupby(['subject', 'run', 'block', 'trial']).apply(summarize_trial_saccades).droplevel(-1)
beh1.join(s_summary).groupby(['p_left', 'first_saccade']).size()
# Out:
# p_left  first_saccade
# 0.55    left_option      121
#         right_option     118
# 1.00    left_option      169
#         right_option      70
# dtype: int64

# %%
s_summary.groupby(['n_saccades']).size()
# Out:
# n_saccades
# 0      2
# 1     20
# 2     98
# 3    135
# 4    143
# 5     55
# 6     20
# 7      7
# dtype: int64

# %%
s_summary = saccades2.groupby(['subject', 'run', 'block', 'trial']).apply(summarize_trial_saccades).droplevel(-1)
beh2.join(s_summary).groupby(['p_left', 'first_saccade']).size()
# Out:
# p_left  first_saccade
# 0.55    left_option      140
#         right_option     100
# 1.00    left_option       39
#         right_option     201
# dtype: int64

# %%
s_summary = saccades2.groupby(['subject', 'run', 'block', 'trial']).apply(summarize_trial_saccades).droplevel(-1)
beh2.join(s_summary).groupby(['p_left']).mean()[['left_duration', 'right_duration']]
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_6970/3576866122.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   beh2.join(s_summary).groupby(['p_left']).mean()[['left_duration', 'right_duration']]
#         left_duration  right_duration
# p_left
# 0.55       936.804167      688.245833
# 1.00       495.191667     1160.841667

# %%
s_summary.groupby(['n_saccades']).size()
# Out:
# n_saccades
# 1      9
# 2    155
# 3    135
# 4    120
# 5     47
# 6     13
# 7      1
# dtype: int64

# %%
s_summary.groupby('first_saccade').size()
# Out:
# first_saccade
# left_option     290
# right_option    188
# dtype: int64

# %%
# Out:
# p_left  first_saccade
# 0.55    left_option      121
#         right_option     118
# 1.00    left_option      169
#         right_option      70
# dtype: int64

# %%
s_summary.join)Beh1
# Out:
#   Cell In[79], line 1
#     s_summary.join)Beh1
#                   ^
# SyntaxError: unmatched ')'

# %%
beh1.join(s_summary)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 beh1.join(s_summary)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/frame.py:9969, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9806 def join(
#    9807     self,
#    9808     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9814     validate: str | None = None,
#    9815 ) -> DataFrame:
#    9816     """
#    9817     Join columns of another DataFrame.
#    9818
#    (...)
#    9967     5  K1  A5   B1
#    9968     """
# -> 9969     return self._join_compat(
#    9970         other,
#    9971         on=on,
#    9972         how=how,
#    9973         lsuffix=lsuffix,
#    9974         rsuffix=rsuffix,
#    9975         sort=sort,
#    9976         validate=validate,
#    9977     )
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/frame.py:10008, in DataFrame._join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9998     if how == "cross":
#    9999         return merge(
#   10000             self,
#   10001             other,
#    (...)
#   10006             validate=validate,
#   10007         )
# > 10008     return merge(
#   10009         self,
#   10010         other,
#   10011         left_on=on,
#   10012         how=how,
#   10013         left_index=on is None,
#   10014         right_index=True,
#   10015         suffixes=(lsuffix, rsuffix),
#   10016         sort=sort,
#   10017         validate=validate,
#   10018     )
#   10019 else:
#   10020     if on is not None:
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/reshape/merge.py:125, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      94 @Substitution("\nleft : DataFrame or named Series")
#      95 @Appender(_merge_doc, indents=0)
#      96 def merge(
#    (...)
#     109     validate: str | None = None,
#     110 ) -> DataFrame:
#     111     op = _MergeOperation(
#     112         left,
#     113         right,
#    (...)
#     123         validate=validate,
#     124     )
# --> 125     return op.get_result(copy=copy)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/reshape/merge.py:776, in _MergeOperation.get_result(self, copy)
#     773 if self.indicator:
#     774     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 776 join_index, left_indexer, right_indexer = self._get_join_info()
#     778 result = self._reindex_and_concat(
#     779     join_index, left_indexer, right_indexer, copy=copy
#     780 )
#     781 result = result.__finalize__(self, method=self._merge_type)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/reshape/merge.py:1015, in _MergeOperation._get_join_info(self)
#    1012 right_ax = self.right.axes[self.axis]
#    1014 if self.left_index and self.right_index and self.how != "asof":
# -> 1015     join_index, left_indexer, right_indexer = left_ax.join(
#    1016         right_ax, how=self.how, return_indexers=True, sort=self.sort
#    1017     )
#    1019 elif self.right_index and self.how == "left":
#    1020     join_index, left_indexer, right_indexer = _left_join_on_index(
#    1021         left_ax, right_ax, self.left_join_keys, sort=self.sort
#    1022     )
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:230, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     221 @functools.wraps(meth)
#     222 def join(
#     223     self,
#    (...)
#     228     sort: bool = False,
#     229 ):
# --> 230     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     231     if not return_indexers:
#     232         return join_index
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:4655, in Index.join(self, other, how, level, return_indexers, sort)
#    4653         pass
#    4654     else:
# -> 4655         return self._join_multi(other, how=how)
#    4657 # join on the level
#    4658 if level is not None and (self._is_multi or other._is_multi):
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:4795, in Index._join_multi(self, other, how)
#    4791     other_jnlevels = other.droplevel(rdrop_names)
#    4793 # Join left and right
#    4794 # Join on same leveled multi-index frames is supported
# -> 4795 join_idx, lidx, ridx = self_jnlevels.join(
#    4796     other_jnlevels, how=how, return_indexers=True
#    4797 )
#    4799 # Restore the dropped levels
#    4800 # Returned index level order is
#    4801 # common levels, ldrop_names, rdrop_names
#    4802 dropped_names = ldrop_names + rdrop_names
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:230, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     221 @functools.wraps(meth)
#     222 def join(
#     223     self,
#    (...)
#     228     sort: bool = False,
#     229 ):
# --> 230     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     231     if not return_indexers:
#     232         return join_index
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:4655, in Index.join(self, other, how, level, return_indexers, sort)
#    4653         pass
#    4654     else:
# -> 4655         return self._join_multi(other, how=how)
#    4657 # join on the level
#    4658 if level is not None and (self._is_multi or other._is_multi):
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:4788, in Index._join_multi(self, other, how)
#    4786 if not len(ldrop_names + rdrop_names):
#    4787     self_jnlevels = self
# -> 4788     other_jnlevels = other.reorder_levels(self.names)
#    4789 else:
#    4790     self_jnlevels = self.droplevel(ldrop_names)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/multi.py:2407, in MultiIndex.reorder_levels(self, order)
#    2405 order = [self._get_level_number(i) for i in order]
#    2406 if len(order) != self.nlevels:
# -> 2407     raise AssertionError(
#    2408         f"Length of order must be same as number of levels ({self.nlevels}), "
#    2409         f"got {len(order)}"
#    2410     )
#    2411 new_levels = [self.levels[i] for i in order]
#    2412 new_codes = [self.codes[i] for i in order]
#
# AssertionError: Length of order must be same as number of levels (5), got 4

# %%
s_summary.describe()
# Out:
#        n_saccades  left_duration  right_duration
# count  480.000000     480.000000      480.000000
# mean     3.175000     715.997917      924.543750
# std      1.135221     476.932060      477.575293
# min      1.000000       0.000000        0.000000
# 25%      2.000000     324.000000      505.000000
# 50%      3.000000     570.000000      892.000000
# 75%      4.000000    1036.250000     1293.750000
# max      7.000000    2137.000000     2293.000000

# %%
saccades1[np.in1d(saccades1.fixation_target, ['left_option', 'right_option'])].groupby(['subject', 'run', 'trial', 'block']).size().describe()
# Out:
# count    478.000000
# mean       3.424686
# std        1.251237
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        7.000000
# dtype: float64

# %%
saccades2[np.in1d(saccades2.fixation_target, ['left_option', 'right_option'])].groupby(['subject', 'run', 'trial', 'block']).size().describe()
# Out:
# count    480.000000
# mean       3.175000
# std        1.135221
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        7.000000
# dtype: float64

# %%
saccades3[np.in1d(saccades3.fixation_target, ['left_option', 'right_option'])].groupby(['subject', 'run', 'trial', 'block']).size().describe()
# Out:
# count    472.000000
# mean       2.201271
# std        0.900435
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        5.000000
# dtype: float64

# %%
messages
# Out:
# subject  run  block  trial  type
# 01       1    1      1      rfx          812658
#                             gfx          813490
#                             response     816196
#                      2      rfx          818317
#                             gfx          819144
#                                          ...
#          5    4      23     gfx         3821684
#                             response    3824712
#                      24     rfx         3826452
#                             gfx         3827266
#                             response    3829840
# Name: timestamp, Length: 1440, dtype: int64

# %%
rts = messages.unstack('type')
rts = (rts['response'] - rts['gfx']).to_frame('rt_')

# %%
beh1 = beh1.join(rts)

# %%
import matplotlib.pyplot as plt
beh1
tmp = saccades1.groupby(['subject', 'run', 'block', 'trial'])[['fixation_duration']].sum().join(beh1)

sns.lmplot(x='fixation_duration', y='rt', data=tmp.reset_index())

plt.plot([500, 4000], [.5, 4])

# %%
beh1
# Out:
#                                       accuracy     rt  leftRight  pressedKey  \
# subject run block trial exptype
# 01      1   1     1     symbolic             1  1.215          1          75
#                   2     symbolic             1  0.737         -1          77
#                   3     symbolic             1  0.920         -1          77
#                   4     symbolic             1  0.965         -1          77
#                   5     symbolic             1  1.218          1          75
# ...                                        ...    ...        ...         ...
#         5   3     20    non-symbolic         1  2.274          1          75
#                   21    non-symbolic         1  1.512          1          75
#                   22    non-symbolic         1  2.088          1          75
#                   23    non-symbolic         0  0.711         -1          77
#                   24    non-symbolic         0  0.739         -1          77
#
#                                       n_safe  n_risky  constSide  \
# subject run block trial exptype
# 01      1   1     1     symbolic          14       47          0
#                   2     symbolic           5        6          0
#                   3     symbolic          14       17          0
#                   4     symbolic          10       12          0
#                   5     symbolic          14       28          0
# ...                                      ...      ...        ...
#         5   3     20    non-symbolic       5       14          0
#                   21    non-symbolic      10       40          0
#                   22    non-symbolic      20       80          0
#                   23    non-symbolic      14       40          0
#                   24    non-symbolic       5       20          0
#
#                                       correct_perm  reset    onset  n_left  \
# subject run block trial exptype
# 01      1   1     1     symbolic                -1     -1    6.065      14
#                   2     symbolic                 1     -1   11.708       5
#                   3     symbolic                 1     -1   17.284      14
#                   4     symbolic                 1     -1   22.882      10
#                   5     symbolic                -1     -1   28.471      14
# ...                                            ...    ...      ...     ...
#         5   3     20    non-symbolic            -1     -1  390.330       5
#                   21    non-symbolic            -1     -1  395.918      10
#                   22    non-symbolic            -1     -1  401.525      20
#                   23    non-symbolic            -1     -1  407.125      14
#                   24    non-symbolic            -1     -1  412.714       5
#
#                                       n_right  p_left  p_right  chose_risky  \
# subject run block trial exptype
# 01      1   1     1     symbolic           47     1.0     0.55          1.0
#                   2     symbolic            6     1.0     0.55          0.0
#                   3     symbolic           17     1.0     0.55          0.0
#                   4     symbolic           12     1.0     0.55          0.0
#                   5     symbolic           28     1.0     0.55          1.0
# ...                                       ...     ...      ...          ...
#         5   3     20    non-symbolic       14     1.0     0.55          1.0
#                   21    non-symbolic       40     1.0     0.55          1.0
#                   22    non-symbolic       80     1.0     0.55          1.0
#                   23    non-symbolic       40     1.0     0.55          0.0
#                   24    non-symbolic       20     1.0     0.55          0.0
#
#                                       log(risky/safe)   rt_
# subject run block trial exptype
# 01      1   1     1     symbolic             1.211090  2706
#                   2     symbolic             0.182322  2181
#                   3     symbolic             0.194156  2370
#                   4     symbolic             0.182322  2409
#                   5     symbolic             0.693147  2662
# ...                                               ...   ...
#         5   3     20    non-symbolic         1.029619  3725
#                   21    non-symbolic         1.386294  2960
#                   22    non-symbolic         1.386294  3540
#                   23    non-symbolic         1.049822  2162
#                   24    non-symbolic         1.386294  2188
#
# [480 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
beh1
tmp = saccades1.groupby(['subject', 'run', 'block', 'trial'])[['fixation_duration']].sum().join(beh1)

sns.lmplot(x='rt_', y='rt', data=tmp.reset_index())

plt.plot([500, 4000], [.5, 4])

# %%
import matplotlib.pyplot as plt
beh1
tmp = saccades1.groupby(['subject', 'run', 'block', 'trial'])[['fixation_duration']].sum().join(beh1)

sns.lmplot(x='fixation_duration', y='rt_', data=tmp.reset_index())

plt.plot([500, 4000], [.5, 4])

# %%
import matplotlib.pyplot as plt
tmp = saccades2.groupby(['subject', 'run', 'block', 'trial'])[['fixation_duration']].sum().join(beh2)

sns.lmplot(x='fixation_duration', y='rt', data=tmp.reset_index())

plt.plot([500, 4000], [.5, 4])

# %%
saccades1
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             19   L         813584        30
#                         813926             20   L         813944        20
#                         814086             21   L         814126        42
#                         814396             22   L         814402         8
#                         814496             23   L         814524        30
# ...                                       ...  ..            ...       ...
#         5   4     96    3828268          1436   L        3828292        26
#                         3828602          1437   L        3828654        54
#                         3828906          1438   L        3828960        56
#                         3829218          1439   L        3829262        46
#                         3829456          1440   L        3829496        42
#
#                                          start_x  start_y  end_x  end_y   amp  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             667.1    515.9  538.8  464.5  4.38
#                         813926             542.1    467.1  499.1  499.3  1.66
#                         814086             508.7    491.3  652.3  502.7  4.61
#                         814396             668.6    519.8  655.2  517.0  0.44
#                         814496             656.7    511.8  818.0  497.0  5.16
# ...                                          ...      ...    ...    ...   ...
#         5   4     96    3828268            745.6    499.6  641.3  491.5  3.35
#                         3828602            658.0    488.2  811.0  507.9  4.91
#                         3828906            816.0    488.1  514.5  493.8  9.60
#                         3829218            493.6    500.8  536.6  501.3  1.37
#                         3829456            549.1    483.7  630.1  489.5  2.60
#
#                                          peak_velocity  fixation_duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813556                     273                360
#                         813926                     136                182
#                         814086                     451                276
#                         814396                      61                122
#                         814496                     421                268
# ...                                                ...                ...
#         5   4     96    3828268                    276                362
#                         3828602                    371                306
#                         3828906                    574                302
#                         3829218                    125                234
#                         3829456                    276                344
#
#                                         fixation_target
# subject run block trial start_timestamp
# 01      1   1     1     813556              center_left
#                         813926              left_option
#                         814086                 fixation
#                         814396                 fixation
#                         814496             right_option
# ...                                                 ...
#         5   4     96    3828268                fixation
#                         3828602            right_option
#                         3828906             left_option
#                         3829218             left_option
#                         3829456                fixation
#
# [3963 rows x 12 columns]

# %%
beh1
# Out:
#                                       accuracy     rt  leftRight  pressedKey  \
# subject run exptype      block trial
# 1       1   symbolic     1     1             1  1.215          1          75
#                                2             1  0.737         -1          77
#                                3             1  0.920         -1          77
#                                4             1  0.965         -1          77
#                                5             1  1.218          1          75
# ...                                        ...    ...        ...         ...
#         5   non-symbolic 3     20            1  2.274          1          75
#                                21            1  1.512          1          75
#                                22            1  2.088          1          75
#                                23            0  0.711         -1          77
#                                24            0  0.739         -1          77
#
#                                       n_safe  n_risky  constSide  \
# subject run exptype      block trial
# 1       1   symbolic     1     1          14       47          0
#                                2           5        6          0
#                                3          14       17          0
#                                4          10       12          0
#                                5          14       28          0
# ...                                      ...      ...        ...
#         5   non-symbolic 3     20          5       14          0
#                                21         10       40          0
#                                22         20       80          0
#                                23         14       40          0
#                                24          5       20          0
#
#                                       correct_perm  reset    onset  n_left  \
# subject run exptype      block trial
# 1       1   symbolic     1     1                -1     -1    6.065      14
#                                2                 1     -1   11.708       5
#                                3                 1     -1   17.284      14
#                                4                 1     -1   22.882      10
#                                5                -1     -1   28.471      14
# ...                                            ...    ...      ...     ...
#         5   non-symbolic 3     20               -1     -1  390.330       5
#                                21               -1     -1  395.918      10
#                                22               -1     -1  401.525      20
#                                23               -1     -1  407.125      14
#                                24               -1     -1  412.714       5
#
#                                       n_right  p_left  p_right  chose_risky  \
# subject run exptype      block trial
# 1       1   symbolic     1     1           47     1.0     0.55          1.0
#                                2            6     1.0     0.55          0.0
#                                3           17     1.0     0.55          0.0
#                                4           12     1.0     0.55          0.0
#                                5           28     1.0     0.55          1.0
# ...                                       ...     ...      ...          ...
#         5   non-symbolic 3     20          14     1.0     0.55          1.0
#                                21          40     1.0     0.55          1.0
#                                22          80     1.0     0.55          1.0
#                                23          40     1.0     0.55          0.0
#                                24          20     1.0     0.55          0.0
#
#                                       log(risky/safe)
# subject run exptype      block trial
# 1       1   symbolic     1     1             1.211090
#                                2             0.182322
#                                3             0.194156
#                                4             0.182322
#                                5             0.693147
# ...                                               ...
#         5   non-symbolic 3     20            1.029619
#                                21            1.386294
#                                22            1.386294
#                                23            1.049822
#                                24            1.386294
#
# [480 rows x 16 columns]

# %%
import numpy as np

def merge_fixations(d):

    d['previous_fixation_target'] = d['fixation_target'].shift(1)

    result = []

    n = 1
    duration = 0.0

    for ix, row in d.iterrows():
        if (row.fixation_target == row['previous_fixation_target']) or (pd.isnull(row.previous_fixation_target)):
            duration += row.fixation_duration
        else:
            result.append({'duration':duration, 'fixation_target':row.previous_fixation_target})
            duration = row.fixation_duration
            n += 1

    if duration != 0:
        result.append({'duration':duration, 'fixation_target':row.fixation_target})

    return pd.DataFrame(result, index=pd.Index(np.arange(1, n+1), name='n'))

# %%
saccades1
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             19   L         813584        30
#                         813926             20   L         813944        20
#                         814086             21   L         814126        42
#                         814396             22   L         814402         8
#                         814496             23   L         814524        30
# ...                                       ...  ..            ...       ...
#         5   4     24    3828268          1436   L        3828292        26
#                         3828602          1437   L        3828654        54
#                         3828906          1438   L        3828960        56
#                         3829218          1439   L        3829262        46
#                         3829456          1440   L        3829496        42
#
#                                          start_x  start_y  end_x  end_y   amp  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             667.1    515.9  538.8  464.5  4.38
#                         813926             542.1    467.1  499.1  499.3  1.66
#                         814086             508.7    491.3  652.3  502.7  4.61
#                         814396             668.6    519.8  655.2  517.0  0.44
#                         814496             656.7    511.8  818.0  497.0  5.16
# ...                                          ...      ...    ...    ...   ...
#         5   4     24    3828268            745.6    499.6  641.3  491.5  3.35
#                         3828602            658.0    488.2  811.0  507.9  4.91
#                         3828906            816.0    488.1  514.5  493.8  9.60
#                         3829218            493.6    500.8  536.6  501.3  1.37
#                         3829456            549.1    483.7  630.1  489.5  2.60
#
#                                          peak_velocity  fixation_duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813556                     273                360
#                         813926                     136                182
#                         814086                     451                276
#                         814396                      61                122
#                         814496                     421                268
# ...                                                ...                ...
#         5   4     24    3828268                    276                362
#                         3828602                    371                306
#                         3828906                    574                302
#                         3829218                    125                234
#                         3829456                    276                344
#
#                                         fixation_target
# subject run block trial start_timestamp
# 01      1   1     1     813556              center_left
#                         813926              left_option
#                         814086                 fixation
#                         814396                 fixation
#                         814496             right_option
# ...                                                 ...
#         5   4     24    3828268                fixation
#                         3828602            right_option
#                         3828906             left_option
#                         3829218             left_option
#                         3829456                fixation
#
# [3963 rows x 12 columns]

# %%
saccades1.groupby(['subject', 'run', 'block', 'trial'])[['fixation_duration']].sum()
# Out:
#                          fixation_duration
# subject run block trial
# 01      1   1     1                   2612
#                   2                   1941
#                   3                   2339
#                   4                   2321
#                   5                   2530
# ...                                    ...
#         5   4     20                  2143
#                   21                  1872
#                   22                  1174
#                   23                  2042
#                   24                  2068
#
# [480 rows x 1 columns]

# %%
beh1
# Out:
#                                       accuracy     rt  leftRight  pressedKey  \
# subject run exptype      block trial
# 1       1   symbolic     1     1             1  1.215          1          75
#                                2             1  0.737         -1          77
#                                3             1  0.920         -1          77
#                                4             1  0.965         -1          77
#                                5             1  1.218          1          75
# ...                                        ...    ...        ...         ...
#         5   non-symbolic 3     236           1  2.274          1          75
#                                237           1  1.512          1          75
#                                238           1  2.088          1          75
#                                239           0  0.711         -1          77
#                                240           0  0.739         -1          77
#
#                                       n_safe  n_risky  constSide  \
# subject run exptype      block trial
# 1       1   symbolic     1     1          14       47          0
#                                2           5        6          0
#                                3          14       17          0
#                                4          10       12          0
#                                5          14       28          0
# ...                                      ...      ...        ...
#         5   non-symbolic 3     236         5       14          0
#                                237        10       40          0
#                                238        20       80          0
#                                239        14       40          0
#                                240         5       20          0
#
#                                       correct_perm  reset    onset  n_left  \
# subject run exptype      block trial
# 1       1   symbolic     1     1                -1     -1    6.065      14
#                                2                 1     -1   11.708       5
#                                3                 1     -1   17.284      14
#                                4                 1     -1   22.882      10
#                                5                -1     -1   28.471      14
# ...                                            ...    ...      ...     ...
#         5   non-symbolic 3     236              -1     -1  390.330       5
#                                237              -1     -1  395.918      10
#                                238              -1     -1  401.525      20
#                                239              -1     -1  407.125      14
#                                240              -1     -1  412.714       5
#
#                                       n_right  p_left  p_right  chose_risky  \
# subject run exptype      block trial
# 1       1   symbolic     1     1           47     1.0     0.55          1.0
#                                2            6     1.0     0.55          0.0
#                                3           17     1.0     0.55          0.0
#                                4           12     1.0     0.55          0.0
#                                5           28     1.0     0.55          1.0
# ...                                       ...     ...      ...          ...
#         5   non-symbolic 3     236         14     1.0     0.55          1.0
#                                237         40     1.0     0.55          1.0
#                                238         80     1.0     0.55          1.0
#                                239         40     1.0     0.55          0.0
#                                240         20     1.0     0.55          0.0
#
#                                       log(risky/safe)
# subject run exptype      block trial
# 1       1   symbolic     1     1             1.211090
#                                2             0.182322
#                                3             0.194156
#                                4             0.182322
#                                5             0.693147
# ...                                               ...
#         5   non-symbolic 3     236           1.029619
#                                237           1.386294
#                                238           1.386294
#                                239           1.049822
#                                240           1.386294
#
# [480 rows x 16 columns]

# %%
saccades1.groupby(['subject', 'run', 'trial'])

# %%
# Out:
#                          duration
# subject run block trial
# 01      1   1     1           356
#                   2           178
#                   3           264
#                   4           150
#                   5           248
# ...                           ...
#         5   4     20          446
#                   21          212
#                   22          212
#                   23          168
#                   24          520
#
# [480 rows x 1 columns]

# %%
beh1.join()
# Out:
#                                       accuracy     rt  leftRight  pressedKey  \
# subject run exptype      block trial
# 1       1   symbolic     1     1             1  1.215          1          75
#                                2             1  0.737         -1          77
#                                3             1  0.920         -1          77
#                                4             1  0.965         -1          77
#                                5             1  1.218          1          75
# ...                                        ...    ...        ...         ...
#         5   non-symbolic 3     236           1  2.274          1          75
#                                237           1  1.512          1          75
#                                238           1  2.088          1          75
#                                239           0  0.711         -1          77
#                                240           0  0.739         -1          77
#
#                                       n_safe  n_risky  constSide  \
# subject run exptype      block trial
# 1       1   symbolic     1     1          14       47          0
#                                2           5        6          0
#                                3          14       17          0
#                                4          10       12          0
#                                5          14       28          0
# ...                                      ...      ...        ...
#         5   non-symbolic 3     236         5       14          0
#                                237        10       40          0
#                                238        20       80          0
#                                239        14       40          0
#                                240         5       20          0
#
#                                       correct_perm  reset    onset  n_left  \
# subject run exptype      block trial
# 1       1   symbolic     1     1                -1     -1    6.065      14
#                                2                 1     -1   11.708       5
#                                3                 1     -1   17.284      14
#                                4                 1     -1   22.882      10
#                                5                -1     -1   28.471      14
# ...                                            ...    ...      ...     ...
#         5   non-symbolic 3     236              -1     -1  390.330       5
#                                237              -1     -1  395.918      10
#                                238              -1     -1  401.525      20
#                                239              -1     -1  407.125      14
#                                240              -1     -1  412.714       5
#
#                                       n_right  p_left  p_right  chose_risky  \
# subject run exptype      block trial
# 1       1   symbolic     1     1           47     1.0     0.55          1.0
#                                2            6     1.0     0.55          0.0
#                                3           17     1.0     0.55          0.0
#                                4           12     1.0     0.55          0.0
#                                5           28     1.0     0.55          1.0
# ...                                       ...     ...      ...          ...
#         5   non-symbolic 3     236         14     1.0     0.55          1.0
#                                237         40     1.0     0.55          1.0
#                                238         80     1.0     0.55          1.0
#                                239         40     1.0     0.55          0.0
#                                240         20     1.0     0.55          0.0
#
#                                       log(risky/safe)
# subject run exptype      block trial
# 1       1   symbolic     1     1             1.211090
#                                2             0.182322
#                                3             0.194156
#                                4             0.182322
#                                5             0.693147
# ...                                               ...
#         5   non-symbolic 3     236           1.029619
#                                237           1.386294
#                                238           1.386294
#                                239           1.049822
#                                240           1.386294
#
# [480 rows x 16 columns]

# %%
saccades1.groupby(['subject', 'run', 'block', 'trial']).apply(merge_fixations).head(50)
# Out:
#                            duration fixation_target
# subject run block trial n
# 01      1   1     1     1     360.0     center_left
#                         2     182.0     left_option
#                         3     398.0        fixation
#                         4     268.0    right_option
#                         5     408.0        fixation
#                         6     234.0    right_option
#                         7     562.0     left_option
#                         8     200.0        fixation
#                   2     1    1458.0        fixation
#                         2     266.0     center_left
#                         3     217.0    right_option
#                   3     1    1700.0        fixation
#                         2     208.0     left_option
#                         3     234.0    right_option
#                         4     197.0        fixation
#                   4     1     248.0    center_right
#                         2    1810.0        fixation
#                         3     263.0    right_option
#                   5     1    1812.0        fixation
#                         2     364.0    right_option
#                         3     354.0        fixation
#                   6     1    1522.0        fixation
#                         2     248.0     left_option
#                         3     294.0    right_option
#                         4     112.0        fixation
#                   7     1    1594.0        fixation
#                         2     392.0    right_option
#                         3     507.0     left_option
#                   8     1     212.0        fixation
#                         2     338.0    right_option
#                         3    1132.0        fixation
#                         4     352.0    right_option
#                         5     292.0        fixation
#                   9     1     998.0        fixation
#                         2     248.0    right_option
#                         3     210.0        fixation
#                         4     216.0    right_option
#                         5     310.0     left_option
#                         6     230.0        fixation
#                         7      48.0    right_option
#                   10    1     638.0        fixation
#                         2     156.0    center_right
#                         3     910.0        fixation
#                         4     274.0    right_option
#                         5     199.0        fixation
#                   11    1    1582.0        fixation
#                         2     282.0    right_option
#                         3     322.0     left_option
#                   12    1     666.0        fixation
#                         2     538.0    right_option

# %%
merge_fixations(saccades1)
# Out:
# nan False
# center_left False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# center_left False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# center_right False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# center_right False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# right_option False
# right_option False
# fixation False
# right_option False
# left_option False
# fixation False
# center_left False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# center_right False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# center_right False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# outside_left False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# center_right False
# fixation False
# right_option False
# right_option False
# left_option False
# fixation False
# right_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# outside_right False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# center_right False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# center_right False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# outside_right False
# outside_right False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# fixation False
# right_option False
# outside_right False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# center_left False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# center_right False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# right_option False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# center_right False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# center_left False
# left_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# right_option False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# outside_right False
# right_option False
# left_option False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# center_left False
# right_option False
# center_right False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# outside_right False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# fixation False
# right_option False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# right_option False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# center_left False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# center_left False
# right_option False
# fixation False
# fixation False
# right_option False
# right_option False
# center_left False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# right_option False
# right_option False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# center_right False
# center_right False
# right_option False
# right_option False
# right_option False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# left_option False
# center_right False
# right_option False
# fixation False
# right_option False
# fixation False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# center_right False
# fixation False
# fixation False
# left_option False
# center_left False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# right_option False
# center_left False
# center_right False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# center_left False
# left_option False
# right_option False
# center_left False
# fixation False
# left_option False
# fixation False
# center_right False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# right_option False
# right_option False
# fixation False
# center_left False
# fixation False
# fixation False
# left_option False
# fixation False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# center_right False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# left_option False
# fixation False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# center_left False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# center_left False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# center_left False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# fixation False
# right_option False
# right_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# fixation False
# right_option False
# left_option False
# center_right False
# right_option False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# right_option False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# center_right False
# right_option False
# left_option False
# right_option False
# outside_right False
# fixation False
# left_option False
# left_option False
# fixation False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# outside_left False
# outside_left False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# center_right False
# right_option False
# left_option False
# left_option False
# outside_left False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# outside_right False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# outside_right False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# left_option False
# center_right False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# right_option False
# outside_right False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# right_option False
# center_left False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# center_left False
# left_option False
# fixation False
# right_option False
# right_option False
# fixation False
# fixation False
# right_option False
# center_left False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# center_right False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# right_option False
# right_option False
# center_right False
# fixation False
# fixation False
# right_option False
# fixation False
# center_right False
# fixation False
# fixation False
# right_option False
# center_left False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# fixation False
# center_left False
# left_option False
# right_option False
# right_option False
# fixation False
# center_left False
# left_option False
# right_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# center_left False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# outside_right False
# right_option False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# right_option False
# center_right False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# right_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# outside_right False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# outside_right False
# left_option False
# right_option False
# outside_right False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# fixation False
# right_option False
# right_option False
# left_option False
# outside_left False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# center_right False
# right_option False
# left_option False
# right_option False
# center_right False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# outside_right False
# right_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# center_right False
# right_option False
# left_option False
# right_option False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# center_right False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# outside_right False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# outside_right False
# fixation False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# center_right False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# right_option False
# fixation False
# fixation False
# right_option False
# center_left False
# left_option False
# center_left False
# right_option False
# fixation False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# center_left False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# center_left False
# center_left False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# center_left False
# right_option False
# fixation False
# fixation False
# center_right False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# center_left False
# right_option False
# right_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# outside_left False
# outside_left False
# outside_left False
# outside_left False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# right_option False
# center_left False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# center_right False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# center_right False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# center_right False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# left_option False
# outside_left False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# fixation False
# fixation False
# center_left False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# center_left False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# center_right False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# center_right False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# outside_right False
# center_right False
# fixation False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# center_left False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# outside_right False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# outside_right False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# center_right False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# center_left False
# left_option False
# fixation False
# left_option False
# right_option False
# center_left False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# center_left False
# right_option False
# fixation False
# center_left False
# right_option False
# center_left False
# fixation False
# center_right False
# left_option False
# center_left False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# fixation False
# center_left False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# right_option False
# fixation False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# right_option False
# center_right False
# fixation False
# left_option False
# left_option False
# right_option False
# center_left False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# left_option False
# left_option False
# center_left False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# right_option False
# center_left False
# fixation False
# center_left False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# fixation False
# left_option False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# left_option False
# fixation False
# right_option False
# right_option False
# fixation False
# center_left False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# right_option False
# right_option False
# left_option False
# fixation False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# right_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# right_option False
# right_option False
# fixation False
# fixation False
# center_right False
# right_option False
# right_option False
# center_right False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# center_right False
# outside_right False
# center_right False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# center_left False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# outside_left False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# right_option False
# center_right False
# fixation False
# right_option False
# left_option False
# right_option False
# left_option False
# center_left False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# right_option False
# outside_right False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# outside_right False
# fixation False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# center_right False
# fixation False
# center_right False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# center_right False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# fixation False
# right_option False
# fixation False
# right_option False
# center_right False
# fixation False
# fixation False
# outside_right False
# left_option False
# outside_right False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# right_option False
# right_option False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# outside_left False
# outside_left False
# left_option False
# right_option False
# left_option False
# right_option False
# right_option False
# fixation False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# left_option False
# outside_left False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# center_left False
# center_left False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# center_right False
# right_option False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# fixation False
# left_option False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# outside_left False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# outside_right False
# right_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# center_left False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# center_left False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# fixation False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# outside_left False
# outside_left False
# left_option False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# outside_left False
# right_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# outside_right False
# right_option False
# left_option False
# left_option False
# right_option False
# outside_right False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# outside_right False
# left_option False
# left_option False
# center_left False
# right_option False
# left_option False
# right_option False
# left_option False
# outside_left False
# left_option False
# left_option False
# center_left False
# right_option False
# right_option False
# fixation False
# outside_right False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# outside_right False
# outside_right False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# outside_left False
# outside_left False
# outside_left False
# outside_left False
# outside_left False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# outside_left False
# outside_left False
# outside_left False
# outside_left False
# outside_left False
# left_option False
# right_option False
# right_option False
# right_option False
# outside_right False
# outside_right False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# right_option False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# outside_right False
# center_right False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# ...
# right_option False
# right_option False
# right_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# center_left False
# left_option False
# left_option False
# right_option False
# outside_right False
# outside_right False
# right_option False
# left_option False
# left_option False
# right_option False
# center_left False
# left_option False
# fixation False
# center_left False
# fixation False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# center_left False
# right_option False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# center_left False
# right_option False
# center_right False
# right_option False
# right_option False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# center_left False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# fixation False
# right_option False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# right_option False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# outside_right False
# left_option False
# left_option False
# right_option False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# center_left False
# right_option False
# right_option False
# left_option False
# center_left False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# outside_left False
# outside_left False
# outside_left False
# left_option False
# right_option False
# right_option False
# left_option False
# outside_left False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# outside_left False
# fixation False
# right_option False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# left_option False
# center_left False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# left_option False
# center_right False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# fixation False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# outside_right False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# center_left False
# center_left False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# center_left False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# right_option False
# center_left False
# left_option False
# fixation False
# right_option False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# outside_right False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# center_right False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# center_left False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# center_right False
# right_option False
# outside_left False
# left_option False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# center_left False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# left_option False
# center_right False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# fixation False
# right_option False
# left_option False
# right_option False
# center_right False
# left_option False
# left_option False
# left_option False
# right_option False
# outside_right False
# center_right False
# fixation False
# fixation False
# right_option False
# right_option False
# left_option False
# right_option False
# right_option False
# center_left False
# left_option False
# left_option False
# center_right False
# right_option False
# fixation False
# fixation False
# right_option False
# right_option False
# fixation False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# left_option False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# center_left False
# fixation False
# outside_right False
# fixation False
# center_left False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# center_left False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# center_left False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# outside_right False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# outside_right False
# fixation False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# outside_left False
# fixation False
# left_option False
# right_option False
# outside_right False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# left_option False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# fixation False
# right_option False
# right_option False
# right_option False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# right_option False
# right_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# fixation False
# right_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# center_left False
# left_option False
# right_option False
# left_option False
# center_left False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# right_option False
# fixation False
# right_option False
# outside_right False
# fixation False
# left_option False
# left_option False
# left_option False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# left_option False
# right_option False
# fixation False
# left_option False
# left_option False
# left_option False
# center_right False
# left_option False
# fixation False
# left_option False
# left_option False
# left_option False
# center_right False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# fixation False
# center_left False
# left_option False
# left_option False
# fixation False
# center_left False
# right_option False
# left_option False
# right_option False
# left_option False
# left_option False
# right_option False
# right_option False
# fixation False
# fixation False
# fixation False
# right_option False
# center_left False
# right_option False
# fixation False
# right_option False
# left_option False
# fixation False
# right_option False
# fixation False
# fixation False
# fixation False
# fixation False
# right_option False
# left_option False
# left_option False
# fixation False
# left_option False
# left_option False
# fixation False
# right_option False
# left_option False
# right_option False
# fixation False
# fixation False
# left_option False
# fixation False
# left_option False
# right_option False
# left_option False
# left_option False
# left_option False
# right_option False
# left_option False
# fixation False
# fixation False
# left_option False
# left_option False
# right_option False
# center_left False
# left_option False
# left_option False
# fixation False
# fixation False
# left_option False
# center_left False
# center_right False
# fixation False
# right_option False
# left_option False
# left_option False
#       duration fixation_target
# n
# 1        360.0     left_option
# 2        182.0        fixation
# 3        398.0    right_option
# 4        268.0        fixation
# 5        408.0    right_option
# ...        ...             ...
# 2470     230.0        fixation
# 2471     362.0    right_option
# 2472     306.0     left_option
# 2473     536.0        fixation
# 2474     344.0        fixation
#
# [2474 rows x 2 columns]

# %%
saccades1['fixation_target'].shift(-1)
# Out:
# subject  run  block  trial  start_timestamp
# 01       1    1      1      813556              left_option
#                             813926                 fixation
#                             814086                 fixation
#                             814396             right_option
#                             814496                 fixation
#                                                    ...
#          5    4      24     3828268            right_option
#                             3828602             left_option
#                             3828906             left_option
#                             3829218                fixation
#                             3829456                     NaN
# Name: fixation_target, Length: 3963, dtype: category
# Categories (7, object): ['outside_left' < 'left_option' < 'center_left' < 'fixation' < 'center_right' < 'right_option' < 'outside_right']

# %%
messages = messages.unstack("type")

# %%
saccades_per_block = saccades1

def get_durations(df):
    durations =  df.iloc[1:]['end_timestamp'].values - df.iloc[:-1]['end_timestamp']
    durations.index = df.iloc[:-1].index

    # durations = durations.append(df.iloc[-1]['end_timestamp'], messages)
    last_trial = df.iloc[-1]
    durations = pd.concat((durations, pd.Series([messages.loc[last_trial.name[:4], 'response'] - last_trial['end_timestamp']], index=df.iloc[-1:].index)))
    durations = durations
    return durations

saccades_per_block['fixation_duration'] = saccades_per_block.groupby(['subject', 'run', 'block', 'trial'], group_keys=False).apply(get_durations)
saccades_per_block = saccades_per_block[saccades_per_block.fixation_duration > 0.0]

# %%
saccades_per_block.sort_values('fixation_duration')
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      2   4     18    1958252          1327   L        1958308        58
#         1   2     21    1067724           745   L        1067738        16
#         2   2     18    1678544           649   L        1678606        64
#         5   3     17    3650604           971   L        3650674        72
#         3   1     19    2180722           257   L        2180746        26
# ...                                       ...  ..            ...       ...
#         5   3     3     3570370           755   L        3570386        18
#         1   3     24    1221750          1195   L        1221770        22
#         4   2     15    2897658           664   L        2897726        70
#             3     18    3054340          1026   L        3054366        28
#             4     18    3194000          1326   L        3194032        34
#
#                                          start_x  start_y  end_x  end_y  \
# subject run block trial start_timestamp
# 01      2   4     18    1958252            720.8    448.6  430.3  491.9
#         1   2     21    1067724           1014.8    467.1  993.9  487.4
#         2   2     18    1678544            925.2    430.5  508.0  520.8
#         5   3     17    3650604            371.8    437.8  917.4  463.3
#         3   1     19    2180722            873.6    544.6  791.5  528.2
# ...                                          ...      ...    ...    ...
#         5   3     3     3570370            624.9    425.2  616.8  455.6
#         1   3     24    1221750            646.5    519.0  631.2  476.4
#         4   2     15    2897658            936.1    763.3  493.9  397.6
#             3     18    3054340            486.3    511.9  637.9  484.6
#             4     18    3194000            624.5    482.9  655.8  475.9
#
#                                            amp  peak_velocity  \
# subject run block trial start_timestamp
# 01      2   4     18    1958252           9.34            452
#         1   2     21    1067724           0.87             83
#         2   2     18    1678544          13.44            605
#         5   3     17    3650604          17.15            666
#         3   1     19    2180722           2.64            205
# ...                                        ...            ...
#         5   3     3     3570370           0.93             80
#         1   3     24    1221750           1.33            101
#         4   2     15    2897658          17.28            735
#             3     18    3054340           4.92            409
#             4     18    3194000           1.03            175
#
#                                          fixation_duration fixation_target
# subject run block trial start_timestamp
# 01      2   4     18    1958252                          1     left_option
#         1   2     21    1067724                          1   outside_right
#         2   2     18    1678544                          3     left_option
#         5   3     17    3650604                          5    right_option
#         3   1     19    2180722                          5    right_option
# ...                                                    ...             ...
#         5   3     3     3570370                       1376        fixation
#         1   3     24    1221750                       1398        fixation
#         4   2     15    2897658                       1452     left_option
#             3     18    3054340                       1464        fixation
#             4     18    3194000                       1564        fixation
#
# [3963 rows x 12 columns]

# %%
saccades1.loc[('01', 2, 4, 18)]
# Out:
#                     n eye  end_timestamp  duration  start_x  start_y  end_x  \
# start_timestamp
# 1955674          1317   L        1955700        28    485.9    340.5  380.6
# 1955970          1318   L        1956026        58    385.0    315.3  596.8
# 1956274          1319   L        1956318        46    606.1    497.8  385.2
# 1956520          1320   L        1956538        20    383.6    266.0  336.8
# 1956840          1321   L        1956862        24    324.8    277.2  413.7
# 1957078          1322   L        1957118        42    422.1    255.3  289.9
# 1957290          1323   L        1957330        42    277.4    322.6  373.2
# 1957438          1324   L        1957500        64    389.7    420.1  885.6
# 1957730          1325   L        1957762        34    902.3    463.0  946.7
# 1958106          1326   L        1958154        50    961.9    489.9  736.5
# 1958252          1327   L        1958308        58    720.8    448.6  430.3
#
#                  end_y    amp  peak_velocity  fixation_duration  \
# start_timestamp
# 1955674          288.6   3.68            258                326
# 1955970          473.5   8.18            491                292
# 1956274          265.5   9.76            521                220
# 1956520          267.4   1.47            125                324
# 1956840          270.6   2.81            211                256
# 1957078          298.9   4.34            364                212
# 1957290          409.8   3.91            415                170
# 1957438          444.9  15.66            739                262
# 1957730          478.1   1.46            188                392
# 1958106          454.9   7.18            454                154
# 1958252          491.9   9.34            452                  1
#
#                 fixation_target
# start_timestamp
# 1955674             left_option
# 1955970                fixation
# 1956274             left_option
# 1956520             left_option
# 1956840             left_option
# 1957078             left_option
# 1957290             left_option
# 1957438            right_option
# 1957730            right_option
# 1958106            center_right
# 1958252             left_option

# %%
saccades1.sort_values('fixation_duration')
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      4   4     5     3123982          1159   L        3124196       216
#         3   4     13    2567036          1345   L        2567262       228
#         5   4     13    3768192          1281   L        3768454       264
#                   14    3773880          1299   L        3774160       282
#         3   2     18    2315510           630   L        2315686       178
# ...                                       ...  ..            ...       ...
#         5   3     3     3570370           755   L        3570386        18
#         1   3     24    1221750          1195   L        1221770        22
#         4   2     15    2897658           664   L        2897726        70
#             3     18    3054340          1026   L        3054366        28
#             4     18    3194000          1326   L        3194032        34
#
#                                          start_x  start_y  end_x  end_y  \
# subject run block trial start_timestamp
# 01      4   4     5     3123982            687.1    534.7  657.9  564.0
#         3   4     13    2567036            373.8    496.9  578.2  386.8
#         5   4     13    3768192            441.7    491.5  529.1  512.5
#                   14    3773880            424.6    487.5  551.8  520.2
#         3   2     18    2315510            996.1    489.1  907.2  364.0
# ...                                          ...      ...    ...    ...
#         5   3     3     3570370            624.9    425.2  616.8  455.6
#         1   3     24    1221750            646.5    519.0  631.2  476.4
#         4   2     15    2897658            936.1    763.3  493.9  397.6
#             3     18    3054340            486.3    511.9  637.9  484.6
#             4     18    3194000            624.5    482.9  655.8  475.9
#
#                                            amp  peak_velocity  \
# subject run block trial start_timestamp
# 01      4   4     5     3123982           1.26            363
#         3   4     13    2567036           7.24            742
#         5   4     13    3768192           2.85           2104
#                   14    3773880           4.15           1526
#         3   2     18    2315510           4.55           2033
# ...                                        ...            ...
#         5   3     3     3570370           0.93             80
#         1   3     24    1221750           1.33            101
#         4   2     15    2897658          17.28            735
#             3     18    3054340           4.92            409
#             4     18    3194000           1.03            175
#
#                                          fixation_duration fixation_target
# subject run block trial start_timestamp
# 01      4   4     5     3123982                       -198        fixation
#         3   4     13    2567036                       -141        fixation
#         5   4     13    3768192                       -107     left_option
#                   14    3773880                        -82     center_left
#         3   2     18    2315510                        -81    right_option
# ...                                                    ...             ...
#         5   3     3     3570370                       1328        fixation
#         1   3     24    1221750                       1340        fixation
#         4   2     15    2897658                       1402     left_option
#             3     18    3054340                       1420        fixation
#             4     18    3194000                       1538        fixation
#
# [4026 rows x 12 columns]

# %%
saccades1.loc[('01', 3, 4, 13)]
# Out:
#                     n eye  end_timestamp  duration  start_x  start_y  end_x  \
# start_timestamp
# 2563956          1332   L        2563972        18    655.9    256.9  654.1
# 2564188          1333   L        2564232        46    652.2    300.4  673.3
# 2564554          1334   L        2564620        68    693.1    507.7  382.3
# 2564836          1335   L        2564892        58    399.7    256.7  292.3
# 2565062          1336   L        2565112        52    293.6    426.6  391.7
# 2565332          1337   L        2565350        20    387.9    275.3  390.3
# 2565516          1338   L        2565574        60    386.1    273.1  503.1
# 2565688          1339   L        2565746        60    504.4    464.7  892.4
# 2565952          1340   L        2566026        76    918.2    482.0  413.1
# 2566166          1341   L        2566188        24    424.1    470.2  336.9
# 2566348          1342   L        2566414        68    358.1    487.1  914.4
# 2566674          1343   L        2566740        68    946.6    457.2  454.8
# 2566920          1344   L        2566950        32    428.0    494.7  371.4
# 2567036          1345   L        2567262       228    373.8    496.9  578.2
#
#                  end_y    amp  peak_velocity  fixation_duration  \
# start_timestamp
# 2563956          290.4   0.99            114                216
# 2564188          455.7   4.60            476                322
# 2564554          297.7  11.63            464                216
# 2564836          430.6   6.06            397                170
# 2565062          293.9   4.92            492                220
# 2565332          256.7   0.55             78                166
# 2565516          447.3   6.30            406                114
# 2565688          463.8  12.32            713                206
# 2565952          485.4  15.91            678                140
# 2566166          491.5   2.81            230                160
# 2566348          459.8  17.46            760                260
# 2566674          475.9  15.50            637                180
# 2566920          498.4   1.79            194                 86
# 2567036          386.8   7.24            742               -141
#
#                 fixation_target
# start_timestamp
# 2563956                fixation
# 2564188                fixation
# 2564554             left_option
# 2564836             left_option
# 2565062             left_option
# 2565332             left_option
# 2565516             left_option
# 2565688            right_option
# 2565952             left_option
# 2566166             left_option
# 2566348            right_option
# 2566674             left_option
# 2566920             left_option
# 2567036                fixation

# %%
3123998 - 3123982
# Out:
# 16

# %%
messages.loc[('01', 4, 4, 5)]
# Out:
# type
# rfx         3120395
# gfx         3121205
# response    3123998
# Name: timestamp, dtype: int64

# %%
saccades1[saccades1.fixation_duration < 0]
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      1   1     8     855032            143   L         855064        34
#             2     5     978314            471   L         978356        44
#                   13    1022992           612   L        1023040        50
#                   15    1034278           649   L        1034342        66
#                   19    1056332           712   L        1056442       112
# ...                                       ...  ..            ...       ...
#         5   3     1     3561198           729   L        3561242        46
#                   10    3611554           854   L        3611612        60
#             4     13    3768192          1281   L        3768454       264
#                   14    3773880          1299   L        3774160       282
#                   23    3824408          1427   L        3824748       342
#
#                                          start_x  start_y  end_x  end_y  \
# subject run block trial start_timestamp
# 01      1   1     8     855032             617.0    505.7  637.4  514.1
#             2     5     978314             973.4    523.9  925.8  358.3
#                   13    1022992            590.4    410.9  435.3  440.6
#                   15    1034278            381.2    443.4  823.8  416.0
#                   19    1056332            904.4    493.4  633.5  400.9
# ...                                          ...      ...    ...    ...
#         5   3     1     3561198            343.4    288.6  365.5  411.1
#                   10    3611554            926.2    431.9  695.6  465.7
#             4     13    3768192            441.7    491.5  529.1  512.5
#                   14    3773880            424.6    487.5  551.8  520.2
#                   23    3824408            457.8    488.4  558.0  433.6
#
#                                            amp  peak_velocity  \
# subject run block trial start_timestamp
# 01      1   1     8     855032            0.70            146
#             2     5     978314            4.99            217
#                   13    1022992           5.03            437
#                   15    1034278          14.05            668
#                   19    1056332           9.02            517
# ...                                        ...            ...
#         5   3     1     3561198           3.62            358
#                   10    3611554           7.37            422
#             4     13    3768192           2.85           2104
#                   14    3773880           4.15           1526
#                   23    3824408           3.58           3046
#
#                                          fixation_duration fixation_target
# subject run block trial start_timestamp
# 01      1   1     8     855032                          -2        fixation
#             2     5     978314                         -18    right_option
#                   13    1022992                        -18     left_option
#                   15    1034278                        -24    right_option
#                   19    1056332                        -10        fixation
# ...                                                    ...             ...
#         5   3     1     3561198                        -32     left_option
#                   10    3611554                        -30        fixation
#             4     13    3768192                       -107     left_option
#                   14    3773880                        -82     center_left
#                   23    3824408                        -36     center_left
#
# [61 rows x 12 columns]

# %%
sns.histplot(saccades1['fixation_duration'])
sns.histplot(saccades2['fixation_duration'])
# Out:
# <Axes: xlabel='fixation_duration', ylabel='Count'>

# %%
saccades1
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             19   L         813584        30
#                         813926             20   L         813944        20
#                         814086             21   L         814126        42
#                         814396             22   L         814402         8
#                         814496             23   L         814524        30
# ...                                       ...  ..            ...       ...
#         5   4     24    3828268          1436   L        3828292        26
#                         3828602          1437   L        3828654        54
#                         3828906          1438   L        3828960        56
#                         3829218          1439   L        3829262        46
#                         3829456          1440   L        3829496        42
#
#                                          start_x  start_y  end_x  end_y   amp  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             667.1    515.9  538.8  464.5  4.38
#                         813926             542.1    467.1  499.1  499.3  1.66
#                         814086             508.7    491.3  652.3  502.7  4.61
#                         814396             668.6    519.8  655.2  517.0  0.44
#                         814496             656.7    511.8  818.0  497.0  5.16
# ...                                          ...      ...    ...    ...   ...
#         5   4     24    3828268            745.6    499.6  641.3  491.5  3.35
#                         3828602            658.0    488.2  811.0  507.9  4.91
#                         3828906            816.0    488.1  514.5  493.8  9.60
#                         3829218            493.6    500.8  536.6  501.3  1.37
#                         3829456            549.1    483.7  630.1  489.5  2.60
#
#                                          peak_velocity  fixation_duration
# subject run block trial start_timestamp
# 01      1   1     1     813556                     273                342
#                         813926                     136                142
#                         814086                     451                270
#                         814396                      61                 94
#                         814496                     421                238
# ...                                                ...                ...
#         5   4     24    3828268                    276                310
#                         3828602                    371                252
#                         3828906                    574                258
#                         3829218                    125                194
#                         3829456                    276                344
#
# [4026 rows x 11 columns]

# %%
def get_durations(df):
    durations =  df.iloc[1:].index.get_level_values('start_timestamp') - df.iloc[:-1]['end_timestamp']
    durations.index = df.iloc[:-1].index

    # durations = durations.append(df.iloc[-1]['end_timestamp'], messages)
    last_trial = df.iloc[-1]
    durations = pd.concat((durations, pd.Series([messages.loc[last_trial.name[:4] + ('response',)] - last_trial['end_timestamp']], index=df.iloc[-1:].index)))
    return durations

print(saccades1)
print(saccades1.groupby(['subject', 'run', 'block', 'trial'], group_keys=False).apply(get_durations))

# saccades_per_block['fixation_duration'] = saccades_per_block.groupby(['subject', 'run', 'block', 'trial'], group_keys=False).apply(get_durations)
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             19   L         813584        30
#                         813926             20   L         813944        20
#                         814086             21   L         814126        42
#                         814396             22   L         814402         8
#                         814496             23   L         814524        30
# ...                                       ...  ..            ...       ...
#         5   4     24    3828268          1436   L        3828292        26
#                         3828602          1437   L        3828654        54
#                         3828906          1438   L        3828960        56
#                         3829218          1439   L        3829262        46
#                         3829456          1440   L        3829496        42
#
#                                          start_x  start_y  end_x  end_y   amp  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             667.1    515.9  538.8  464.5  4.38
#                         813926             542.1    467.1  499.1  499.3  1.66
#                         814086             508.7    491.3  652.3  502.7  4.61
#                         814396             668.6    519.8  655.2  517.0  0.44
#                         814496             656.7    511.8  818.0  497.0  5.16
# ...                                          ...      ...    ...    ...   ...
#         5   4     24    3828268            745.6    499.6  641.3  491.5  3.35
#                         3828602            658.0    488.2  811.0  507.9  4.91
#                         3828906            816.0    488.1  514.5  493.8  9.60
#                         3829218            493.6    500.8  536.6  501.3  1.37
#                         3829456            549.1    483.7  630.1  489.5  2.60
#
#                                          peak_velocity
# subject run block trial start_timestamp
# 01      1   1     1     813556                     273
#                         813926                     136
#                         814086                     451
#                         814396                      61
#                         814496                     421
# ...                                                ...
#         5   4     24    3828268                    276
#                         3828602                    371
#                         3828906                    574
#                         3829218                    125
#                         3829456                    276
#
# [4026 rows x 10 columns]
# subject  run  block  trial  start_timestamp
# 01       1    1      1      813556             342
#                             813926             142
#                             814086             270
#                             814396              94
#                             814496             238
#                                               ...
#          5    4      24     3828268            310
#                             3828602            252
#                             3828906            258
#                             3829218            194
#                             3829456            344
# Length: 4026, dtype: int64

# %%
sns.distplot(saccades1['end_x'])
sns.distplot(saccades2['end_x'])
sns.distplot(saccades3['end_x'])
sns.distplot(saccades4['end_x'])
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_61973/1885469205.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(saccades1['end_x'])
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_61973/1885469205.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(saccades2['end_x'])
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_61973/1885469205.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(saccades3['end_x'])
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_61973/1885469205.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(saccades4['end_x'])
# <Axes: xlabel='end_x', ylabel='Density'>

# %%
saccades1

# %%
import statsmodels.api as sm

# %%
saccades3['end_x'].plot()
# Out:
# <Axes: xlabel='subject,run,block,trial,start_timestamp'>

# %%
sm.OLS(saccades3.end_x, sm.add_constant(saccades3.end_timestamp) ).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  end_x   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     146.5
# Date:                Thu, 03 Aug 2023   Prob (F-statistic):           4.66e-33
# Time:                        09:51:20   Log-Likelihood:                -22250.
# No. Observations:                3470   AIC:                         4.450e+04
# Df Residuals:                    3468   BIC:                         4.452e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           892.1774     21.281     41.923      0.000     850.453     933.902
# end_timestamp -3.443e-05   2.84e-06    -12.103      0.000      -4e-05   -2.89e-05
# ==============================================================================
# Omnibus:                        5.385   Durbin-Watson:                   1.473
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                5.331
# Skew:                           0.094   Prob(JB):                       0.0696
# Kurtosis:                       3.039   Cond. No.                     6.36e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.36e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
saccades['end_x'].plot()
# Out:
# <Axes: xlabel='subject,run,block,trial,start_timestamp'>

# %%
messages
# Out:
# subject  run  block  trial  type
# 03       1    1      1      rfx         5913266
#                             gfx         5914110
#                             response    5916574
#                      2      rfx         5918913
#                             gfx         5919743
#                                          ...
#          5    4      23     gfx         8914074
#                             response    8916395
#                      24     rfx         8918844
#                             gfx         8919653
#                             response    8922090
# Name: timestamp, Length: 1440, dtype: int64

# %%
messages = messages.unstack('type')

# %%
saccades_per_block = []
for ix, row in messages.iterrows():
    s = saccades.loc[(ix[0], ix[1], slice(row.gfx, row.response)), :]
    saccades_per_block.append(s.droplevel([0, 1]))

saccades_per_block = pd.concat(saccades_per_block, keys=messages.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 2
#       1 saccades_per_block = []
# ----> 2 for ix, row in messages.iterrows():
#       3     s = saccades.loc[(ix[0], ix[1], slice(row.gfx, row.response)), :]
#       4     saccades_per_block.append(s.droplevel([0, 1]))
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
saccades1
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             19   L         813584        30
#                         813926             20   L         813944        20
#                         814086             21   L         814126        42
#                         814396             22   L         814402         8
#                         814496             23   L         814524        30
# ...                                       ...  ..            ...       ...
#         5   4     24    3828268          1436   L        3828292        26
#                         3828602          1437   L        3828654        54
#                         3828906          1438   L        3828960        56
#                         3829218          1439   L        3829262        46
#                         3829456          1440   L        3829496        42
#
#                                          start_x  start_y  end_x  end_y   amp  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             667.1    515.9  538.8  464.5  4.38
#                         813926             542.1    467.1  499.1  499.3  1.66
#                         814086             508.7    491.3  652.3  502.7  4.61
#                         814396             668.6    519.8  655.2  517.0  0.44
#                         814496             656.7    511.8  818.0  497.0  5.16
# ...                                          ...      ...    ...    ...   ...
#         5   4     24    3828268            745.6    499.6  641.3  491.5  3.35
#                         3828602            658.0    488.2  811.0  507.9  4.91
#                         3828906            816.0    488.1  514.5  493.8  9.60
#                         3829218            493.6    500.8  536.6  501.3  1.37
#                         3829456            549.1    483.7  630.1  489.5  2.60
#
#                                          peak_velocity fixation_target
# subject run block trial start_timestamp
# 01      1   1     1     813556                     273     center_left
#                         813926                     136     left_option
#                         814086                     451        fixation
#                         814396                      61        fixation
#                         814496                     421    right_option
# ...                                                ...             ...
#         5   4     24    3828268                    276        fixation
#                         3828602                    371    right_option
#                         3828906                    574     left_option
#                         3829218                    125     left_option
#                         3829456                    276        fixation
#
# [4026 rows x 11 columns]

# %%
messages
# Out:
# subject  run  block  trial  type
# 03       1    1      1      rfx         5913266
#                             gfx         5914110
#                             response    5916574
#                      2      rfx         5918913
#                             gfx         5919743
#                                          ...
#          5    4      23     gfx         8914074
#                             response    8916395
#                      24     rfx         8918844
#                             gfx         8919653
#                             response    8922090
# Name: timestamp, Length: 1441, dtype: int64

# %%
saccades
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 03      1   1     1     5914520            29   L        5914552        34
#                         5915482            30   L        5915492        12
#                         5915790            31   L        5915806        18
#                         5915874            32   L        5915930        58
#                         5916396            33   L        5916454        60
# ...                                       ...  ..            ...       ...
#         5   4     24    8920008          1653   L        8920018        12
#                         8920220          1654   L        8920228        10
#                         8920438          1655   L        8920450        14
#                         8921200          1656   L        8921204         6
#                         8921670          1657   L        8921832       164
#
#                                          start_x  start_y  end_x  end_y  \
# subject run block trial start_timestamp
# 03      1   1     1     5914520            786.0    503.8  821.5  473.3
#                         5915482            817.7    478.5  799.2  470.6
#                         5915790            807.3    470.9  824.4  469.6
#                         5915874            820.4    472.8  491.4  459.4
#                         5916396            496.5    476.6  860.6  482.0
# ...                                          ...      ...    ...    ...
#         5   4     24    8920008            445.0    451.5  436.6  465.9
#                         8920220            446.3    466.5  461.7  471.9
#                         8920438            453.3    456.1  429.5  461.4
#                         8921200            453.2    466.8  444.8  464.1
#                         8921670            446.8    469.7  440.4  426.0
#
#                                            amp  peak_velocity
# subject run block trial start_timestamp
# 03      1   1     1     5914520           1.43            184
#                         5915482           0.63             75
#                         5915790           0.55             85
#                         5915874          10.48            825
#                         5916396          11.58            762
# ...                                        ...            ...
#         5   4     24    8920008           0.50             54
#                         8920220           0.51             68
#                         8920438           0.77             64
#                         8921200           0.28             63
#                         8921670           1.28            184
#
# [3470 rows x 10 columns]

# %%
messages = sub1.get_eyetracker_timings()

# %%
d = get_durations(saccades1.iloc[:10])

# %%
saccades1['fixation_duration'] = saccades1.groupby(['subject', 'run', 'block', 'trial'], group_keys=False).apply(get_durations)

# %%
saccades1
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             19   L         813584        30
#                         813926             20   L         813944        20
#                         814086             21   L         814126        42
#                         814396             22   L         814402         8
#                         814496             23   L         814524        30
# ...                                       ...  ..            ...       ...
#         5   4     24    3828268          1436   L        3828292        26
#                         3828602          1437   L        3828654        54
#                         3828906          1438   L        3828960        56
#                         3829218          1439   L        3829262        46
#                         3829456          1440   L        3829496        42
#
#                                          start_x  start_y  end_x  end_y   amp  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             667.1    515.9  538.8  464.5  4.38
#                         813926             542.1    467.1  499.1  499.3  1.66
#                         814086             508.7    491.3  652.3  502.7  4.61
#                         814396             668.6    519.8  655.2  517.0  0.44
#                         814496             656.7    511.8  818.0  497.0  5.16
# ...                                          ...      ...    ...    ...   ...
#         5   4     24    3828268            745.6    499.6  641.3  491.5  3.35
#                         3828602            658.0    488.2  811.0  507.9  4.91
#                         3828906            816.0    488.1  514.5  493.8  9.60
#                         3829218            493.6    500.8  536.6  501.3  1.37
#                         3829456            549.1    483.7  630.1  489.5  2.60
#
#                                          peak_velocity fixation_target  \
# subject run block trial start_timestamp
# 01      1   1     1     813556                     273     center_left
#                         813926                     136     left_option
#                         814086                     451        fixation
#                         814396                      61        fixation
#                         814496                     421    right_option
# ...                                                ...             ...
#         5   4     24    3828268                    276        fixation
#                         3828602                    371    right_option
#                         3828906                    574     left_option
#                         3829218                    125     left_option
#                         3829456                    276        fixation
#
#                                          fixation_duration
# subject run block trial start_timestamp
# 01      1   1     1     813556                         342
#                         813926                         142
#                         814086                         270
#                         814396                          94
#                         814496                         238
# ...                                                    ...
#         5   4     24    3828268                        310
#                         3828602                        252
#                         3828906                        258
#                         3829218                        194
#                         3829456                        344
#
# [4026 rows x 12 columns]

# %%
sns.jointplot?
# Out:
# Signature:
# sns.jointplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     kind='scatter',
#     height=6,
#     ratio=5,
#     space=0.2,
#     dropna=False,
#     xlim=None,
#     ylim=None,
#     color=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     marginal_ticks=False,
#     joint_kws=None,
#     marginal_kws=None,
#     **kwargs,
# )
# Docstring:
# Draw a plot of two variables with bivariate and univariate graphs.
#
# This function provides a convenient interface to the :class:`JointGrid`
# class, with several canned plot kinds. This is intended to be a fairly
# lightweight wrapper; if you need more flexibility, you should use
# :class:`JointGrid` directly.
#
# Parameters
# ----------
# data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#     Input data structure. Either a long-form collection of vectors that can be
#     assigned to named variables or a wide-form dataset that will be internally
#     reshaped.
# x, y : vectors or keys in ``data``
#     Variables that specify positions on the x and y axes.
# hue : vector or key in ``data``
#     Semantic variable that is mapped to determine the color of plot elements.
#     Semantic variable that is mapped to determine the color of plot elements.
# kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }
#     Kind of plot to draw. See the examples for references to the underlying functions.
# height : numeric
#     Size of the figure (it will be square).
# ratio : numeric
#     Ratio of joint axes height to marginal axes height.
# space : numeric
#     Space between the joint and marginal axes
# dropna : bool
#     If True, remove observations that are missing from ``x`` and ``y``.
# {x, y}lim : pairs of numbers
#     Axis limits to set before plotting.
# color : :mod:`matplotlib color <matplotlib.colors>`
#     Single color specification for when hue mapping is not used. Otherwise, the
#     plot will try to hook into the matplotlib property cycle.
# palette : string, list, dict, or :class:`matplotlib.colors.Colormap`
#     Method for choosing the colors to use when mapping the ``hue`` semantic.
#     String values are passed to :func:`color_palette`. List or dict values
#     imply categorical mapping, while a colormap object implies numeric mapping.
# hue_order : vector of strings
#     Specify the order of processing and plotting for categorical levels of the
#     ``hue`` semantic.
# hue_norm : tuple or :class:`matplotlib.colors.Normalize`
#     Either a pair of values that set the normalization range in data units
#     or an object that will map from data units into a [0, 1] interval. Usage
#     implies numeric mapping.
# marginal_ticks : bool
#     If False, suppress ticks on the count/density axis of the marginal plots.
# {joint, marginal}_kws : dicts
#     Additional keyword arguments for the plot components.
# kwargs
#     Additional keyword arguments are passed to the function used to
#     draw the plot on the joint Axes, superseding items in the
#     ``joint_kws`` dictionary.
#
# Returns
# -------
# :class:`JointGrid`
#     An object managing multiple subplots that correspond to joint and marginal axes
#     for plotting a bivariate relationship or distribution.
#
# See Also
# --------
# JointGrid : Set up a figure with joint and marginal views on bivariate data.
# PairGrid : Set up a figure with joint and marginal views on multiple variables.
# jointplot : Draw multiple bivariate plots with univariate marginal distributions.
#
# Examples
# --------
#
# .. include:: ../docstrings/jointplot.rst
# File:      ~/mambaforge/lib/python3.10/site-packages/seaborn/axisgrid.py
# Type:      function

# %%
pd.concat((saccades1, saccades2, saccades3, saccades4)).groupby(['subject']).describe()['end_x']
# Out:
#           count        mean         std    min      25%     50%      75%  \
# subject
# 01       4026.0  631.455564  197.001745 -432.2  480.000  638.50  781.325
# 02       3586.0  735.308951  216.792975   99.3  529.975  724.30  921.375
# 03       3470.0  636.390086  150.509891   64.3  528.500  646.65  721.950
# 04       3973.0  634.309414  152.373678  244.6  527.700  635.00  715.700
#
#             max
# subject
# 01       1915.4
# 02       2157.1
# 03       1107.2
# 04       1879.7

# %%
import matplotlib.pyplot as plt

saccades = saccades3

sns.histplot(saccades['end_x'], bins=100)

plt.axvline(saccades['end_x'].median(), c='r', lw=2)
plt.axvline(saccades['end_x'].median() - 75, c='r', lw=2)
plt.axvline(saccades['end_x'].median() + 75, c='r', lw=2)
plt.axvline(saccades['end_x'].median() - 100, c='r', lw=2)
plt.axvline(saccades['end_x'].median() + 100, c='r', lw=2)
plt.axvline(saccades['end_x'].median() + 350, c='r', lw=2)
plt.axvline(saccades['end_x'].median() - 350, c='r', lw=2)

# %%
import numpy as np

def get_fixation_targets(d):

    median = df['end_x'].median()
    bins = [-np.inf, median-350, median-100, median-75, median+75, median+100, median+350, np.inf]

    return pd.cut(df['end_x'], bins=bins, labels=['outside_left', 'left_option', 'center_left', 'fixation', 'center_right', 'right_option', 'outside_right'])

# %%
saccades2['fixation_target'] = get_fixation_targets(saccades2)

saccades2.groupby(['fixation_target']).size()
# Out:
# fixation_target
# outside_left       77
# left_option      1162
# center_left        56
# fixation          764
# center_right       31
# right_option     1433
# outside_right      63
# dtype: int64

# %%
messages
# Out:
# subject  run  block  trial  type
# 03       1    1      1      rfx         5913266
#                             gfx         5914110
#                             response    5916574
#                      2      rfx         5918913
#                             gfx         5919743
#                                          ...
#          5    4      23     gfx         8914074
#                             response    8916395
#                      24     rfx         8918844
#                             gfx         8919653
#                             response    8922090
# Name: timestamp, Length: 1441, dtype: int64

# %%
saccades2.head(20)
# Out:
#                                           n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 02      1   1     1     89456            20   L          89470        16
#                         89640            21   L          89690        52
#                         89846            22   L          89894        50
#                         90146            23   L          90168        24
#                         90346            24   L          90370        26
#                         90578            25   L          90626        50
#                         90832            26   L          90872        42
#                         91110            27   L          91166        58
#                         91380            28   L          91438        60
#                         91656            29   L          91694        40
#                   2     94998            39   L          95022        26
#                         95240            40   L          95286        48
#                         95474            41   L          95520        48
#                         95810            42   L          95874        66
#                         96150            43   L          96176        28
#                         96436            44   L          96468        34
#                         96624            45   L          96682        60
#                         96894            46   L          96920        28
#                         97096            47   L          97132        38
#                         97252            48   L          97304        54
#
#                                          start_x  start_y   end_x  end_y  \
# subject run block trial start_timestamp
# 02      1   1     1     89456             1024.3    303.4  1027.6  325.1
#                         89640             1029.8    338.9   776.6  537.0
#                         89846              769.8    544.7  1033.0  335.0
#                         90146             1027.2    345.5  1043.8  393.0
#                         90346             1035.5    385.9  1028.2  334.2
#                         90578             1030.3    341.3   755.6  529.6
#                         90832              745.8    539.4   994.9  532.6
#                         91110              982.3    526.2   461.7  502.6
#                         91380              450.1    514.0   992.7  392.4
#                         91656              984.5    397.3   768.1  526.2
#                   2     94998             1008.0    475.4   949.0  429.0
#                         95240              938.7    427.1   680.6  443.4
#                         95474              672.3    442.6   440.6  438.1
#                         95810              437.9    440.8  1059.5  423.6
#                         96150             1057.2    422.7   959.6  441.3
#                         96436              950.2    450.3   935.0  558.0
#                         96624              931.4    560.2   445.0  507.5
#                         96894              429.4    513.0   348.6  513.0
#                         97096              353.8    515.4   545.5  521.6
#                         97252              543.1    525.0  1009.8  555.2
#
#                                            amp  peak_velocity fixation_target
# subject run block trial start_timestamp
# 02      1   1     1     89456             0.65             53    right_option
#                         89640             8.65            308        fixation
#                         89846             9.07            407    right_option
#                         90146             1.48            103    right_option
#                         90346             1.56            107    right_option
#                         90578             8.84            376        fixation
#                         90832             6.20            304    right_option
#                         91110            12.87            387     left_option
#                         91380            13.88            465    right_option
#                         91656             6.62            376        fixation
#                   2     94998             2.02            108    right_option
#                         95240             6.46            223        fixation
#                         95474             5.75            202     left_option
#                         95810            15.32            434    right_option
#                         96150             2.48            137    right_option
#                         96436             3.24            211    right_option
#                         96624            12.14            353     left_option
#                         96894             1.98            127    outside_left
#                         97096             4.72            248     left_option
#                         97252            11.60            430    right_option

# %%
saccades1[np.in1d(saccades1['fixation_target'], ['left_option', 'fixatoin', 'right_option'])]
# Out:
#                                             n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813926             20   L         813944        20
#                         814496             23   L         814524        30
#                         815170             26   L         815200        32
#                         815372             27   L         815434        64
#                         815680             28   L         815710        32
# ...                                       ...  ..            ...       ...
#         5   4     23    3823368          1423   L        3823384        18
#                         3824226          1426   L        3824278        54
#                   24    3828602          1437   L        3828654        54
#                         3828906          1438   L        3828960        56
#                         3829218          1439   L        3829262        46
#
#                                          start_x  start_y  end_x  end_y  \
# subject run block trial start_timestamp
# 01      1   1     1     813926             542.1    467.1  499.1  499.3
#                         814496             656.7    511.8  818.0  497.0
#                         815170             650.6    509.3  842.4  510.2
#                         815372             832.2    503.4  496.6  475.9
#                         815680             468.4    480.3  477.7  464.3
# ...                                          ...      ...    ...    ...
#         5   4     23    3823368            456.4    449.6  431.8  452.7
#                         3824226            714.5    495.1  473.5  494.5
#                   24    3828602            658.0    488.2  811.0  507.9
#                         3828906            816.0    488.1  514.5  493.8
#                         3829218            493.6    500.8  536.6  501.3
#
#                                            amp  peak_velocity fixation_target
# subject run block trial start_timestamp
# 01      1   1     1     813926            1.66            136     left_option
#                         814496            5.16            421    right_option
#                         815170            6.11            505    right_option
#                         815372           10.72            577     left_option
#                         815680            0.55            121     left_option
# ...                                        ...            ...             ...
#         5   4     23    3823368           0.79             85     left_option
#                         3824226           7.70            423     left_option
#                   24    3828602           4.91            371    right_option
#                         3828906           9.60            574     left_option
#                         3829218           1.37            125     left_option
#
# [2440 rows x 11 columns]

# %%
saccades1.head(40)
# Out:
#                                           n eye  end_timestamp  duration  \
# subject run block trial start_timestamp
# 01      1   1     1     813556           19   L         813584        30
#                         813926           20   L         813944        20
#                         814086           21   L         814126        42
#                         814396           22   L         814402         8
#                         814496           23   L         814524        30
#                         814762           24   L         814792        32
#                         815008           25   L         815024        18
#                         815170           26   L         815200        32
#                         815372           27   L         815434        64
#                         815680           28   L         815710        32
#                         815950           29   L         815996        48
#                   2     819360           41   L         819384        26
#                         819958           42   L         819976        20
#                         820204           43   L         820226        24
#                         820798           44   L         820842        46
#                         821048           45   L         821108        62
#                   3     824736           53   L         824754        20
#                         825112           54   L         825132        22
#                         825350           55   L         825382        34
#                         825650           56   L         825670        22
#                         825904           57   L         825928        26
#                         826294           58   L         826300         8
#                         826430           59   L         826454        26
#                         826608           60   L         826662        56
#                         826848           61   L         826896        50
#                   4     830384           70   L         830408        26
#                         830634           71   L         830656        24
#                         831548           72   L         831576        30
#                         831742           73   L         831760        20
#                         832026           74   L         832034        10
#                         832428           75   L         832466        40
#                   5     836020           88   L         836040        22
#                         836322           89   L         836350        30
#                         836638           90   L         836654        18
#                         836928           91   L         836944        18
#                         837200           92   L         837222        24
#                         837560           93   L         837600        42
#                         837820           94   L         837852        34
#                         838180           95   L         838216        38
#                         838432           96   L         838452        22
#
#                                          start_x  start_y  end_x  end_y  \
# subject run block trial start_timestamp
# 01      1   1     1     813556             667.1    515.9  538.8  464.5
#                         813926             542.1    467.1  499.1  499.3
#                         814086             508.7    491.3  652.3  502.7
#                         814396             668.6    519.8  655.2  517.0
#                         814496             656.7    511.8  818.0  497.0
#                         814762             806.1    507.6  631.1  514.3
#                         815008             645.4    520.5  654.3  515.7
#                         815170             650.6    509.3  842.4  510.2
#                         815372             832.2    503.4  496.6  475.9
#                         815680             468.4    480.3  477.7  464.3
#                         815950             477.1    465.9  629.7  471.0
#                   2     819360             754.7    487.9  645.6  516.1
#                         819958             657.9    534.2  625.5  511.5
#                         820204             614.8    506.9  667.2  526.1
#                         820798             675.5    523.9  548.4  522.9
#                         821048             532.0    518.9  840.2  509.5
#                   3     824736             669.9    451.0  628.0  459.4
#                         825112             634.4    497.2  592.8  481.9
#                         825350             587.4    492.2  641.6  508.4
#                         825650             646.9    507.4  616.9  499.0
#                         825904             621.3    487.1  631.9  489.2
#                         826294             648.8    492.3  637.6  489.2
#                         826430             646.8    493.2  517.2  479.1
#                         826608             514.7    484.4  816.7  504.8
#                         826848             837.7    509.8  658.2  498.3
#                   4     830384             642.3    503.1  723.1  508.0
#                         830634             716.0    505.7  657.6  522.2
#                         831548             666.8    508.7  686.7  491.4
#                         831742             703.1    481.2  674.7  497.8
#                         832026             683.0    491.9  666.1  493.4
#                         832428             648.0    488.7  778.8  471.9
#                   5     836020             693.4    459.2  630.5  453.2
#                         836322             643.1    456.5  649.6  456.5
#                         836638             646.9    461.7  636.3  452.8
#                         836928             635.4    471.3  618.8  472.1
#                         837200             636.8    483.8  656.9  476.6
#                         837560             663.9    496.6  573.2  510.5
#                         837820             575.1    503.3  832.5  493.6
#                         838180             837.7    509.5  704.1  499.3
#                         838432             698.5    494.5  621.4  495.8
#
#                                            amp  peak_velocity fixation_target
# subject run block trial start_timestamp
# 01      1   1     1     813556            4.38            273     center_left
#                         813926            1.66            136     left_option
#                         814086            4.61            451        fixation
#                         814396            0.44             61        fixation
#                         814496            5.16            421    right_option
#                         814762            5.59            417        fixation
#                         815008            0.32             80        fixation
#                         815170            6.11            505    right_option
#                         815372           10.72            577     left_option
#                         815680            0.55            121     left_option
#                         815950            4.89            423        fixation
#                   2     819360            3.59            288        fixation
#                         819958            1.23             91        fixation
#                         820204            1.77            189        fixation
#                         820798            4.07            328     center_left
#                         821048            9.80            599    right_option
#                   3     824736            1.37            142        fixation
#                         825112            1.41            106        fixation
#                         825350            1.80            242        fixation
#                         825650            0.99            105        fixation
#                         825904            0.35             93        fixation
#                         826294            0.37             61        fixation
#                         826430            4.17            310     left_option
#                         826608            9.64            575    right_option
#                         826848            5.73            447        fixation
#                   4     830384            2.59            212    center_right
#                         830634            1.93            197        fixation
#                         831548            0.81            168        fixation
#                         831742            1.03            110        fixation
#                         832026            0.54             78        fixation
#                         832428            4.21            324    right_option
#                   5     836020            2.03            174        fixation
#                         836322            0.21            118        fixation
#                         836638            0.43             71        fixation
#                         836928            0.53             91        fixation
#                         837200            0.68            106        fixation
#                         837560            2.93            200        fixation
#                         837820            8.22            568    right_option
#                         838180            4.27            253        fixation
#                         838432            2.47            212        fixation

# %%
sns.jointplot(data=p
d.concat((saccades1, saccades2, saccades3)), x='end_x', y='end_y', hue='subject', kind='hist', alpha=.5)

# %%
sns.jointplot(data=pd.concat((saccades1, saccades2, saccades3)), x='end_x', y='end_y', kind="hex", color="#4CB391", hue='subject')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sns.jointplot(data=pd.concat((saccades1, saccades2, saccades3)), x='end_x', y='end_y', kind="hex", color="#4CB391", hue='subject')
#
# File ~/mambaforge/lib/python3.10/site-packages/seaborn/axisgrid.py:2225, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2221 if hue is not None and kind in ["hex", "reg", "resid"]:
#    2222     msg = (
#    2223         f"Use of `hue` with `kind='{kind}'` is not currently supported."
#    2224     )
# -> 2225     raise ValueError(msg)
#    2227 # Make a colormap based off the plot color
#    2228 # (Currently used only for kind="hex")
#    2229 if color is None:
#
# ValueError: Use of `hue` with `kind='hex'` is not currently supported.

# %%
sns.jointplot(data=saccades_per_block, x='start_x', y='start_y', kind="hex", color="#4CB391")

# %%
import seaborn as sns
sns.histplot(saccades_per_block.groupby(['run', 'block', 'trial']).size())
# Out:
# <Axes: ylabel='Count'>

# %%
messages
# Out:
# type                         gfx  response      rfx
# subject run block trial
# 03      1   1     1      5914110   5916574  5913266
#                   2      5919743   5922209  5918913
#                   3      5925330   5927609  5924518
#                   4      5930910   5933210  5930096
#                   5      5936481   5938941  5935673
# ...                          ...       ...      ...
#         5   4     20     8897282   8899463  8896472
#                   21     8902886   8905456  8902074
#                   22     8908463   8911227  8907652
#                   23     8914074   8916395  8913261
#                   24     8919653   8922090  8918844
#
# [480 rows x 3 columns]

# %%
saccades
# Out:
#                                 n eye  end_timestamp  duration  start_x  \
# subject run start_timestamp
# 03      1   5906088             0   L        5906132        46    784.8
#             5906348             1   L        5906374        28    622.7
#             5906492             2   L        5906518        28    575.7
#             5906756             3   L        5906780        26    451.8
#             5906972             4   L        5906996        26    562.4
# ...                           ...  ..            ...       ...      ...
#         5   8927078          1670   L        8927110        34    444.7
#             8927350          1671   L        8927382        34    411.9
#             8927732          1672   L        8927762        32    439.3
#             8928012          1673   L        8928044        34    376.1
#             8928438          1674   L        8928494        58    427.4
#
#                              start_y  end_x  end_y    amp  peak_velocity
# subject run start_timestamp
# 03      1   5906088            496.5  633.3  474.7   4.89            529
#             5906348            477.1  576.1  463.2   1.55            202
#             5906492            472.6  452.1  490.3   3.98            308
#             5906756            492.8  571.7  502.1   3.83            327
#             5906972            494.3  680.7  504.4   3.80            299
# ...                              ...    ...    ...    ...            ...
#         5   8927078            421.7  420.7  460.7   1.37            182
#             8927350            455.3  439.2  377.9   2.41            245
#             8927732            394.2  392.1  507.7   3.61            315
#             8928012            498.3  430.3  469.5   1.90            224
#             8928438            454.4  756.8  628.4  11.58            701
#
# [8260 rows x 10 columns]

# %%
import bambi as bmb
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# WARNING (aesara.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
df = pd.DataFrame(np.random.randn(100, 3), columns=['x', 'y', 'z'])

df['subject'] = np.repeat(np.arange(10)+1, 10)

# %%
model = bmb.Model('y ~ bs(x, df=5)*bs(z, df=5)+(bs(x, df=5)*bs(z, df=5)|subject)', data=df)

idata = model.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 model = bmb.Model('y ~ bs(x, df=5)*bs(z, df=5)+(bs(x, df=5)*bs(z, df=5)|subject)', data=df)
# ----> 3 idata = model.fit()
#
# File ~/mambaforge/lib/python3.10/site-packages/bambi/models.py:267, in Model.fit(self, draws, tune, discard_tuned_samples, omit_offsets, include_mean, inference_method, init, n_init, chains, cores, random_seed, **kwargs)
#     264         inference_method = method
#     266 if not self.built:
# --> 267     self.build()
#     269 # Tell user which event is being modeled
#     270 if isinstance(self.family, univariate.Bernoulli):
#
# File ~/mambaforge/lib/python3.10/site-packages/bambi/models.py:298, in Model.build(self)
#     293 """Set up the model for sampling/fitting.
#     294
#     295 Creates an instance of the underlying PyMC model and adds all the necessary terms to it.
#     296 """
#     297 self.backend = PyMCModel()
# --> 298 self.backend.build(self)
#     299 self.built = True
#
# File ~/mambaforge/lib/python3.10/site-packages/bambi/backend/pymc.py:69, in PyMCModel.build(self, spec)
#      67 self._build_intercept(spec)
#      68 self._build_offsets(spec)
# ---> 69 self._build_common_terms(spec)
#      70 self._build_group_specific_terms(spec)
#      71 self._build_response(spec)
#
# File ~/mambaforge/lib/python3.10/site-packages/bambi/backend/pymc.py:160, in PyMCModel._build_common_terms(self, spec)
#     157     columns.append(data)
#     159 # Column vector of coefficients and design matrix
# --> 160 coefs = at.concatenate(coefs)
#     161 data = np.hstack(columns)
#     163 # If there's an intercept, center the data
#     164 # Also store the design matrix without the intercept to uncenter the intercept later
#
# File ~/mambaforge/lib/python3.10/site-packages/aesara/tensor/basic.py:2620, in concatenate(tensor_list, axis)
#    2613 if not isinstance(tensor_list, (tuple, list)):
#    2614     raise TypeError(
#    2615         "The 'tensors' argument must be either a tuple "
#    2616         "or a list, make sure you did not forget () or [] around "
#    2617         "arguments of concatenate.",
#    2618         tensor_list,
#    2619     )
# -> 2620 return join(axis, *tensor_list)
#
# File ~/mambaforge/lib/python3.10/site-packages/aesara/tensor/basic.py:2445, in join(axis, *tensors_list)
#    2443     return tensors_list[0]
#    2444 else:
# -> 2445     return join_(axis, *tensors_list)
#
# File ~/mambaforge/lib/python3.10/site-packages/aesara/graph/op.py:297, in Op.__call__(self, *inputs, **kwargs)
#     255 r"""Construct an `Apply` node using :meth:`Op.make_node` and return its outputs.
#     256
#     257 This method is just a wrapper around :meth:`Op.make_node`.
#    (...)
#     294
#     295 """
#     296 return_list = kwargs.pop("return_list", False)
# --> 297 node = self.make_node(*inputs, **kwargs)
#     299 if config.compute_test_value != "off":
#     300     compute_test_value(node)
#
# File ~/mambaforge/lib/python3.10/site-packages/aesara/tensor/basic.py:2164, in Join.make_node(self, axis, *tensors)
#    2161 if not tensors:
#    2162     raise ValueError("Cannot join an empty list of tensors")
# -> 2164 tensors = [as_tensor_variable(x) for x in tensors]
#    2165 out_dtype = aes.upcast(*[x.type.dtype for x in tensors])
#    2167 if not builtins.all(targs.type.ndim for targs in tensors):
#
# File ~/mambaforge/lib/python3.10/site-packages/aesara/tensor/basic.py:2164, in <listcomp>(.0)
#    2161 if not tensors:
#    2162     raise ValueError("Cannot join an empty list of tensors")
# -> 2164 tensors = [as_tensor_variable(x) for x in tensors]
#    2165 out_dtype = aes.upcast(*[x.type.dtype for x in tensors])
#    2167 if not builtins.all(targs.type.ndim for targs in tensors):
#
# File ~/mambaforge/lib/python3.10/site-packages/aesara/tensor/__init__.py:49, in as_tensor_variable(x, name, ndim, **kwargs)
#      17 def as_tensor_variable(
#      18     x: TensorLike, name: Optional[str] = None, ndim: Optional[int] = None, **kwargs
#      19 ) -> "TensorVariable":
#      20     """Convert `x` into an equivalent `TensorVariable`.
#      21
#      22     This function can be used to turn ndarrays, numbers, `ScalarType` instances,
#    (...)
#      47
#      48     """
# ---> 49     return _as_tensor_variable(x, name, ndim, **kwargs)
#
# File ~/mambaforge/lib/python3.10/functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/mambaforge/lib/python3.10/site-packages/pymc/pytensorf.py:99, in raise_informative_error(*args, **kwargs)
#      97 @_as_tensor_variable_aesara.register(TensorVariable)
#      98 def raise_informative_error(*args, **kwargs):
# ---> 99     raise TypeError(
#     100         "You are calling an Aesara function with PyTensor variables.\n"
#     101         "Starting with PyMC 5.0, Aesara was replaced by PyTensor (see https://www.pymc.io/blog/pytensor_announcement.html).\n"
#     102         "Replace your import of aesara.tensor with pytensor.tensor.",
#     103     )
#
# TypeError: You are calling an Aesara function with PyTensor variables.
# Starting with PyMC 5.0, Aesara was replaced by PyTensor (see https://www.pymc.io/blog/pytensor_announcement.html).
# Replace your import of aesara.tensor with pytensor.tensor.

# %%
pd.read_csv('/data/ds-riskeye/derivatives/pupil/sub-01/func/sub-01_run-1_gaze.tsv.gz', sep='\t')
# Out:
#          808836        .      ..1      0.0      ..2      ..3  ...       ..4  \
# 0        808838        .        .      0.0        .        .  ...         .
# 1        808840        .        .      0.0        .        .  ...         .
# 2        808842        .        .      0.0        .        .  ...         .
# 3        808844        .        .      0.0        .        .  ...         .
# 4        808846        .        .      0.0        .        .  ...         .
# ...         ...      ...      ...      ...      ...      ...   ...      ...
# 280786  1370410    703.7    527.5   1036.0     -5.7    -19.2  ...    -687.0
# 280787  1370412    702.7    524.8   1037.0        .        .  ...    -697.0
# 280788  1370414    702.5    522.1   1039.0        .        .  ...    -678.0
# 280789  1370416    702.5    522.0   1040.0        .        .  ...    -680.0
# 280790  1370418    702.3    521.9   1041.0        .        .  ...    -681.0
#
#             ..5        . .............
# 0             .        . .............
# 1             .        . .............
# 2             .        . .............
# 3             .        . .............
# 4             .        . .............
# ...         ...                    ...
# 280786   -976.0   -102.9 MAN...BL.T...
# 280787   -955.0   -102.6 MAN...BL..BLR
# 280788   -985.0   -102.4 MAN...BL...L.
# 280789   -987.0   -102.0 MAN...BL....R
# 280790   -975.0   -101.7 MAN...BL....R
#
# [280791 rows x 10 columns]

# %%
pd.read_csv('/data/ds-riskeye/derivatives/pupil/sub-21/func/sub-21_run-1_gaze.tsv.gz', sep='\t')
# Out:
#         15926672        .      ..1      0.0      ..2      ..3  ...
# 0       15926674        .        .      0.0        .        .  ...
# 1       15926676        .        .      0.0        .        .  ...
# 2       15926678        .        .      0.0        .        .  ...
# 3       15926680        .        .      0.0        .        .  ...
# 4       15926682        .        .      0.0        .        .  ...
# ...          ...      ...      ...      ...      ...      ...  ...
# 279562  16485798    672.1    496.2    636.0      0.6     -0.8  ...
# 279563  16485800    672.3    496.3    636.0        .        .  ...
# 279564  16485802    672.2    496.6    636.0        .        .  ...
# 279565  16485804    671.9    496.7    638.0        .        .  ...
# 279566  16485806    671.6    496.5    639.0        .        .  ...
#
# [279567 rows x 7 columns]
